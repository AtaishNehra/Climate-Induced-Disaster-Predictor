# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/ATAISH NEHRA/Downloads/DS5500 Raw datasets/Forest and carbon world only.csv")

# %%
df.columns
# Out:
# Index(['ObjectId', 'Country', 'ISO2', 'ISO3', 'Indicator', 'Unit', 'Source',
#        'CTS_Code', 'CTS_Name', 'CTS_Full_Descriptor', '1992', '1993', '1994',
#        '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003',
#        '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012',
#        '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020'],
#       dtype='object')

# %%
df
# Out:
#    ObjectId Country  ISO2 ISO3                          Indicator  \
# 0      1330   World   NaN  WLD           Carbon stocks in forests
# 1      1331   World   NaN  WLD                        Forest area
# 2      1332   World   NaN  WLD  Index of carbon stocks in forests
# 3      1333   World   NaN  WLD             Index of forest extent
# 4      1334   World   NaN  WLD                          Land area
# 5      1335   World   NaN  WLD               Share of forest area
#
#              Unit                                             Source  \
# 0  Million tonnes  Food and Agriculture Organization of the Unite...
# 1         1000 HA  Food and Agriculture Organization of the Unite...
# 2           Index  Food and Agriculture Organization of the Unite...
# 3           Index  Food and Agriculture Organization of the Unite...
# 4         1000 HA  Food and Agriculture Organization of the Unite...
# 5         Percent  Food and Agriculture Organization of the Unite...
#
# ...

# %%
# Define the columns to keep
columns_to_keep = ['Indicator', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', 
                   '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', 
                   '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020']

# %%
# Filter the DataFrame to keep only the specified columns
df_filtered = df[columns_to_keep]

# %%
# Display the first few rows of the filtered DataFrame
df_filtered.head(6)
# Out:
#                            Indicator          1992          1993  \
# 0           Carbon stocks in forests  2.969488e+05  2.967239e+05
# 1                        Forest area  4.220757e+06  4.212918e+06
# 2  Index of carbon stocks in forests  1.000000e+02  9.992426e+01
# 3             Index of forest extent  1.000000e+02  9.981429e+01
# 4                          Land area  1.299094e+07  1.299057e+07
# 5               Share of forest area  3.249000e+01  3.243060e+01
#
#            1994          1995          1996          1997          1998  \
# 0  2.964990e+05  2.962741e+05  2.960492e+05  2.958243e+05  2.955994e+05
# 1  4.205080e+06  4.197241e+06  4.189403e+06  4.181565e+06  4.173726e+06
# 2  9.984853e+01  9.977279e+01  9.969705e+01  9.962132e+01  9.954558e+01
# 3  9.962858e+01  9.944287e+01  9.925716e+01  9.907145e+01  9.888574e+01
# 4  1.298936e+07  1.298906e+07  1.298901e+07  1.299595e+07  1.299334e+07
# 5  3.237326e+01  3.231367e+01  3.225344e+01  3.217591e+01  3.212203e+01
#
# ...

# %%
# Assuming df_filtered is your current DataFrame
# Pivot the DataFrame
df_pivoted = df_filtered.pivot_table(values=['1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', 
                                             '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', 
                                             '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', 
                                             '2019', '2020'], 
                                     index='Indicator', 
                                     aggfunc='first').transpose()

# %%
# Reset the index to make the years a column
df_pivoted.reset_index(inplace=True)

# %%
df_pivoted.rename(columns={'index': 'Year'}, inplace=True)

# %%
# Display the first few rows of the pivoted DataFrame
df_pivoted
# Out:
# Indicator  Year  Carbon stocks in forests  Forest area  \
# 0          1992               296948.8291  4220756.642
# 1          1993               296723.9289  4212918.252
# 2          1994               296499.0290  4205079.862
# 3          1995               296274.1290  4197241.472
# 4          1996               296049.2285  4189403.083
# 5          1997               295824.3288  4181564.692
# 6          1998               295599.4295  4173726.302
# 7          1999               295374.5288  4165887.912
# 8          2000               295149.6290  4158049.522
# 9          2001               295000.1375  4152876.264
# 10         2002               294850.6476  4147703.007
# 11         2003               294701.1574  4142529.749
# 12         2004               294551.6671  4137356.491
# 13         2005               294402.1767  4132183.233
# 14         2006               294252.6864  4127009.975
# 15         2007               294103.1955  4121836.718
# ...

# %%
# Save the pivoted DataFrame to a CSV file
df_pivoted.to_csv("C:/Users/ATAISH NEHRA/Downloads/Cleaned Datasets/Forest and Carbon_cleaned.csv", index=False)
