# %%
import pandas as pd

# %%
# Replace 'your_dataset.csv' with the path to your dataset
file_path = "C:/Users/ATAISH NEHRA/Downloads/DS5500 Raw datasets/Land cover accounts world only data.csv"

# %%
# Load the dataset
data = pd.read_csv(file_path)

# %%
# Print the column names
print(data.columns.tolist())
# Out:
# ['Column1', 'Country', 'ISO2', 'ISO3', 'Indicator', 'Unit', 'Source', 'CTS_Code', 'CTS_Name', 'CTS_Full_Descriptor', 'Climate_Influence', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020']

# %%
# List of columns to keep
columns_to_keep = ['Indicator', 'Climate_Influence', 
                   '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', 
                   '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', 
                   '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', 
                   '2016', '2017', '2018', '2019', '2020']

# %%
# Filter the DataFrame to keep only the specified columns
data_filtered = data[columns_to_keep]

# data_filtered now contains only the columns specified

# %%
data_filtered
# Out:
#                            Indicator   Climate_Influence          1992  \
# 0  Climate Altering Land Cover Index    Climate altering  9.653648e+01
# 1                   Total Land Cover    Climate altering  1.808245e+06
# 2                   Total Land Cover     Climate neutral  2.729688e+06
# 3                   Total Land Cover  Climate regulating  8.445620e+06
#
#            1993          1994          1995          1996          1997  \
# 0  9.679988e+01  9.660545e+01  9.713551e+01  9.728953e+01  9.752710e+01
# 1  1.832532e+06  1.828851e+06  1.838886e+06  1.841802e+06  1.846299e+06
# 2  2.743915e+06  2.743967e+06  2.743684e+06  2.744038e+06  2.742812e+06
# 3  8.545686e+06  8.549314e+06  8.539562e+06  8.536293e+06  8.533020e+06
#
#            1998          1999  ...          2011          2012          2013  \
# 0  9.781829e+01  9.850464e+01  ...  9.989466e+01  9.985695e+01  9.991792e+01
# 1  1.851811e+06  1.864804e+06  ...  1.893073e+06  1.928202e+06  1.929378e+06
# ...

# %%
# Melt the DataFrame to long format
long_format = data_filtered.melt(id_vars=['Indicator', 'Climate_Influence'], 
                                 var_name='Year', 
                                 value_name='Value')

# %%
# Pivot to get the desired structure
pivoted_data = long_format.pivot_table(index='Year', 
                                       columns=['Indicator', 'Climate_Influence'], 
                                       values='Value')

# %%
# Resetting the index to get 'Year' as a column
pivoted_data.reset_index(inplace=True)

# %%
pivoted_data
# Out:
#     Year  Climate Altering Land Cover Index Climate altering  \
# 0   1992                                          96.536478
# 1   1993                                          96.799882
# 2   1994                                          96.605453
# 3   1995                                          97.135507
# 4   1996                                          97.289526
# 5   1997                                          97.527101
# 6   1998                                          97.818292
# 7   1999                                          98.504636
# 8   2000                                          99.012226
# 9   2001                                          99.175383
# 10  2002                                          99.336617
# 11  2003                                          99.478560
# 12  2004                                          99.862700
# 13  2005                                          99.758721
# 14  2006                                          99.816484
# ...

# %%
pivoted_data.columns = [' '.join(col).strip() for col in pivoted_data.columns.values]

# %%
# Specify the file path and name for your new CSV file
output_file_path = "C:/Users/ATAISH NEHRA/Downloads/Cleaned Datasets/Land Cover Accounts_cleaned.csv"

# Save the DataFrame to a CSV file
pivoted_data.to_csv(output_file_path, index=False)

# 'index=False' ensures that the DataFrame's index (in this case, the 'Year') is not written as a separate column
