# %%
#creating the attention neural network
import tensorflow as tf
import keras
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
# Out:
# WARNING:tensorflow:From C:\Users\seank\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
dataset = pd.read_csv('complete_dataset.csv')

# %%
X = dataset.drop(['Country','Drought', 'Extreme temperature', 'Flood', 'Landslide', 'Storm', 'Total Disasters', 'Wildfire'], axis=1)
Y = dataset[['Total Disasters']].astype(np.float32)

# %%
# Scale the features
scaler_X = MinMaxScaler(feature_range=(0, 1))
X_scaled = scaler_X.fit_transform(X)

# Scale the target
scaler_y = MinMaxScaler(feature_range=(0, 1))
y_scaled = scaler_y.fit_transform(Y)

# %%
# Function to create sequences by country
def create_sequences_by_country(X, y, n_steps, data):
    Xs, ys = [], []
    countries = data['Country'].unique()
    for country in countries:
        country_indices = data[data['Country'] == country].index
        country_data_X = X[country_indices]
        country_data_y = y[country_indices]
        for i in range(len(country_data_X) - n_steps):
            Xs.append(country_data_X[i:(i + n_steps)])
            ys.append(country_data_y[i + n_steps])
    return np.array(Xs), np.array(ys).reshape(-1, 1)

n_steps = 1  # Using 3 years of data to predict the next year
X_seq, y_seq = create_sequences_by_country(X_scaled, y_scaled, n_steps, dataset)

# Split the dataset into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X_seq, y_seq, test_size=0.3, random_state=42)

# %%
print(y_train.shape)
# Out:
# (607, 1)

# %%
'''
This is the one I am currently working on
'''
def attnnk(head, dim, unit, shape):
    
    '''query = tf.keras.layers.Input(shape =(shape[1], shape[2]))
    key = tf.keras.layers.Input(shape =(shape[1], shape[2]))
    value =  tf.keras.layers.Input(shape =(shape[1], shape[2]))'''
    #the reason why it was expecting 3 inputs is because i created 3 inputs
    inp = tf.keras.layers.Input(shape = (shape[1], shape[2]))
    print(inp.shape)
    
    lstm = tf.keras.layers.LSTM(unit, return_sequences = True)(inp)
    
    #this allows for them to exist without needing 3 inputs
    query = tf.keras.layers.Lambda(lambda x: x, name = 'query')(inp)
    key = tf.keras.layers.Lambda(lambda x: x, name = 'key')(inp)
    value = tf.keras.layers.Lambda(lambda x: x, name = 'value')(inp)
    
    attention = tf.keras.layers.MultiHeadAttention(num_heads = head, key_dim = dim, value_dim = dim)(query = query, key = key,value = value)
    
    #attention = tf.keras.layers.Flatten()(attention)
    
    attlstm = tf.keras.layers.Concatenate()([lstm, attention])
    
    drop = tf.keras.layers.Dropout(.1)(attlstm)
    dense = tf.keras.layers.Dense(units = unit, activation = 'ReLU')(drop)
    dense2 = tf.keras.layers.Dense(units = unit, activation = 'ReLU')(dense)
    output = tf.keras.layers.Dense(units = 1, activation = 'softplus')(dense2)
    
    model = tf.keras.Model(inputs = inp, outputs = output)
    output = tf.squeeze(output)
    print(output.shape)
    model.compile(optimizer = 'adam', loss = 'mse', metrics = ['Accuracy', 'AUC', 'MeanSquaredError'])
    
    return model

# %%
epochs = 100
batch = 30
model = attnnk(31,64,21, X_train.shape)
history = model.fit(X_train, y_train, epochs = epochs, batch_size = batch, verbose = 2)
att_pred = model.predict(X_test)
print(att_pred.shape)
# Out:
# WARNING:tensorflow:From C:\Users\seank\anaconda3\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# (None, 1, 22)
# <unknown>
# WARNING:tensorflow:From C:\Users\seank\anaconda3\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/100
# WARNING:tensorflow:From C:\Users\seank\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\seank\anaconda3\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 21/21 - 3s - loss: 0.0763 - Accuracy: 0.0395 - auc: 0.5109 - mean_squared_error: 0.0763 - 3s/epoch - 146ms/step
# Epoch 2/100
# 21/21 - 0s - loss: 0.0268 - Accuracy: 0.0461 - auc: 0.6535 - mean_squared_error: 0.0268 - 83ms/epoch - 4ms/step
# Epoch 3/100
# 21/21 - 0s - loss: 0.0208 - Accuracy: 0.0461 - auc: 0.6572 - mean_squared_error: 0.0208 - 82ms/epoch - 4ms/step
# Epoch 4/100
# 21/21 - 0s - loss: 0.0195 - Accuracy: 0.0461 - auc: 0.6721 - mean_squared_error: 0.0195 - 81ms/epoch - 4ms/step
# Epoch 5/100
# 21/21 - 0s - loss: 0.0191 - Accuracy: 0.0461 - auc: 0.7036 - mean_squared_error: 0.0191 - 78ms/epoch - 4ms/step
# Epoch 6/100
# 21/21 - 0s - loss: 0.0173 - Accuracy: 0.0461 - auc: 0.6966 - mean_squared_error: 0.0173 - 77ms/epoch - 4ms/step
# Epoch 7/100
# 21/21 - 0s - loss: 0.0182 - Accuracy: 0.0461 - auc: 0.7526 - mean_squared_error: 0.0182 - 77ms/epoch - 4ms/step
# Epoch 8/100
# 21/21 - 0s - loss: 0.0187 - Accuracy: 0.0445 - auc: 0.7265 - mean_squared_error: 0.0187 - 75ms/epoch - 4ms/step
# Epoch 9/100
# 21/21 - 0s - loss: 0.0174 - Accuracy: 0.0461 - auc: 0.7078 - mean_squared_error: 0.0174 - 76ms/epoch - 4ms/step
# Epoch 10/100
# 21/21 - 0s - loss: 0.0178 - Accuracy: 0.0461 - auc: 0.6905 - mean_squared_error: 0.0178 - 78ms/epoch - 4ms/step
# Epoch 11/100
# 21/21 - 0s - loss: 0.0190 - Accuracy: 0.0461 - auc: 0.7140 - mean_squared_error: 0.0190 - 77ms/epoch - 4ms/step
# Epoch 12/100
# 21/21 - 0s - loss: 0.0173 - Accuracy: 0.0461 - auc: 0.7082 - mean_squared_error: 0.0173 - 76ms/epoch - 4ms/step
# Epoch 13/100
# 21/21 - 0s - loss: 0.0166 - Accuracy: 0.0461 - auc: 0.7377 - mean_squared_error: 0.0166 - 75ms/epoch - 4ms/step
# Epoch 14/100
# 21/21 - 0s - loss: 0.0168 - Accuracy: 0.0461 - auc: 0.7815 - mean_squared_error: 0.0168 - 77ms/epoch - 4ms/step
# Epoch 15/100
# 21/21 - 0s - loss: 0.0163 - Accuracy: 0.0461 - auc: 0.6875 - mean_squared_error: 0.0163 - 76ms/epoch - 4ms/step
# Epoch 16/100
# 21/21 - 0s - loss: 0.0158 - Accuracy: 0.0461 - auc: 0.7026 - mean_squared_error: 0.0158 - 78ms/epoch - 4ms/step
# Epoch 17/100
# 21/21 - 0s - loss: 0.0158 - Accuracy: 0.0461 - auc: 0.7565 - mean_squared_error: 0.0158 - 75ms/epoch - 4ms/step
# Epoch 18/100
# 21/21 - 0s - loss: 0.0153 - Accuracy: 0.0461 - auc: 0.6930 - mean_squared_error: 0.0153 - 77ms/epoch - 4ms/step
# Epoch 19/100
# 21/21 - 0s - loss: 0.0155 - Accuracy: 0.0461 - auc: 0.7305 - mean_squared_error: 0.0155 - 75ms/epoch - 4ms/step
# Epoch 20/100
# 21/21 - 0s - loss: 0.0155 - Accuracy: 0.0461 - auc: 0.6194 - mean_squared_error: 0.0155 - 76ms/epoch - 4ms/step
# Epoch 21/100
# 21/21 - 0s - loss: 0.0156 - Accuracy: 0.0461 - auc: 0.6522 - mean_squared_error: 0.0156 - 77ms/epoch - 4ms/step
# Epoch 22/100
# 21/21 - 0s - loss: 0.0149 - Accuracy: 0.0461 - auc: 0.6860 - mean_squared_error: 0.0149 - 76ms/epoch - 4ms/step
# Epoch 23/100
# 21/21 - 0s - loss: 0.0159 - Accuracy: 0.0461 - auc: 0.7215 - mean_squared_error: 0.0159 - 75ms/epoch - 4ms/step
# Epoch 24/100
# 21/21 - 0s - loss: 0.0144 - Accuracy: 0.0461 - auc: 0.7730 - mean_squared_error: 0.0144 - 76ms/epoch - 4ms/step
# Epoch 25/100
# 21/21 - 0s - loss: 0.0147 - Accuracy: 0.0461 - auc: 0.6610 - mean_squared_error: 0.0147 - 76ms/epoch - 4ms/step
# Epoch 26/100
# 21/21 - 0s - loss: 0.0147 - Accuracy: 0.0461 - auc: 0.6872 - mean_squared_error: 0.0147 - 77ms/epoch - 4ms/step
# Epoch 27/100
# 21/21 - 0s - loss: 0.0142 - Accuracy: 0.0461 - auc: 0.7159 - mean_squared_error: 0.0142 - 77ms/epoch - 4ms/step
# Epoch 28/100
# 21/21 - 0s - loss: 0.0141 - Accuracy: 0.0461 - auc: 0.6986 - mean_squared_error: 0.0141 - 75ms/epoch - 4ms/step
# Epoch 29/100
# 21/21 - 0s - loss: 0.0139 - Accuracy: 0.0461 - auc: 0.6947 - mean_squared_error: 0.0139 - 76ms/epoch - 4ms/step
# Epoch 30/100
# 21/21 - 0s - loss: 0.0139 - Accuracy: 0.0461 - auc: 0.6983 - mean_squared_error: 0.0139 - 76ms/epoch - 4ms/step
# Epoch 31/100
# 21/21 - 0s - loss: 0.0141 - Accuracy: 0.0461 - auc: 0.7312 - mean_squared_error: 0.0141 - 76ms/epoch - 4ms/step
# Epoch 32/100
# 21/21 - 0s - loss: 0.0133 - Accuracy: 0.0461 - auc: 0.6915 - mean_squared_error: 0.0133 - 75ms/epoch - 4ms/step
# Epoch 33/100
# 21/21 - 0s - loss: 0.0131 - Accuracy: 0.0461 - auc: 0.7201 - mean_squared_error: 0.0131 - 76ms/epoch - 4ms/step
# Epoch 34/100
# 21/21 - 0s - loss: 0.0136 - Accuracy: 0.0461 - auc: 0.6731 - mean_squared_error: 0.0136 - 76ms/epoch - 4ms/step
# Epoch 35/100
# 21/21 - 0s - loss: 0.0143 - Accuracy: 0.0461 - auc: 0.6365 - mean_squared_error: 0.0143 - 76ms/epoch - 4ms/step
# Epoch 36/100
# 21/21 - 0s - loss: 0.0136 - Accuracy: 0.0461 - auc: 0.6288 - mean_squared_error: 0.0136 - 80ms/epoch - 4ms/step
# Epoch 37/100
# 21/21 - 0s - loss: 0.0123 - Accuracy: 0.0461 - auc: 0.6884 - mean_squared_error: 0.0123 - 84ms/epoch - 4ms/step
# Epoch 38/100
# 21/21 - 0s - loss: 0.0135 - Accuracy: 0.0461 - auc: 0.6658 - mean_squared_error: 0.0135 - 77ms/epoch - 4ms/step
# Epoch 39/100
# 21/21 - 0s - loss: 0.0137 - Accuracy: 0.0461 - auc: 0.6373 - mean_squared_error: 0.0137 - 76ms/epoch - 4ms/step
# Epoch 40/100
# 21/21 - 0s - loss: 0.0137 - Accuracy: 0.0461 - auc: 0.7086 - mean_squared_error: 0.0137 - 75ms/epoch - 4ms/step
# Epoch 41/100
# 21/21 - 0s - loss: 0.0143 - Accuracy: 0.0461 - auc: 0.7016 - mean_squared_error: 0.0143 - 77ms/epoch - 4ms/step
# Epoch 42/100
# 21/21 - 0s - loss: 0.0139 - Accuracy: 0.0461 - auc: 0.7229 - mean_squared_error: 0.0139 - 75ms/epoch - 4ms/step
# Epoch 43/100
# 21/21 - 0s - loss: 0.0137 - Accuracy: 0.0461 - auc: 0.6941 - mean_squared_error: 0.0137 - 74ms/epoch - 4ms/step
# Epoch 44/100
# 21/21 - 0s - loss: 0.0136 - Accuracy: 0.0461 - auc: 0.6668 - mean_squared_error: 0.0136 - 75ms/epoch - 4ms/step
# Epoch 45/100
# 21/21 - 0s - loss: 0.0139 - Accuracy: 0.0461 - auc: 0.6744 - mean_squared_error: 0.0139 - 76ms/epoch - 4ms/step
# Epoch 46/100
# 21/21 - 0s - loss: 0.0140 - Accuracy: 0.0461 - auc: 0.6996 - mean_squared_error: 0.0140 - 75ms/epoch - 4ms/step
# Epoch 47/100
# 21/21 - 0s - loss: 0.0133 - Accuracy: 0.0461 - auc: 0.6629 - mean_squared_error: 0.0133 - 76ms/epoch - 4ms/step
# Epoch 48/100
# 21/21 - 0s - loss: 0.0132 - Accuracy: 0.0461 - auc: 0.6673 - mean_squared_error: 0.0132 - 77ms/epoch - 4ms/step
# Epoch 49/100
# 21/21 - 0s - loss: 0.0127 - Accuracy: 0.0461 - auc: 0.6923 - mean_squared_error: 0.0127 - 76ms/epoch - 4ms/step
# Epoch 50/100
# 21/21 - 0s - loss: 0.0124 - Accuracy: 0.0461 - auc: 0.6834 - mean_squared_error: 0.0124 - 76ms/epoch - 4ms/step
# Epoch 51/100
# 21/21 - 0s - loss: 0.0127 - Accuracy: 0.0461 - auc: 0.6955 - mean_squared_error: 0.0127 - 76ms/epoch - 4ms/step
# Epoch 52/100
# 21/21 - 0s - loss: 0.0125 - Accuracy: 0.0461 - auc: 0.6367 - mean_squared_error: 0.0125 - 76ms/epoch - 4ms/step
# Epoch 53/100
# 21/21 - 0s - loss: 0.0135 - Accuracy: 0.0461 - auc: 0.6211 - mean_squared_error: 0.0135 - 78ms/epoch - 4ms/step
# Epoch 54/100
# 21/21 - 0s - loss: 0.0126 - Accuracy: 0.0461 - auc: 0.6320 - mean_squared_error: 0.0126 - 76ms/epoch - 4ms/step
# Epoch 55/100
# 21/21 - 0s - loss: 0.0130 - Accuracy: 0.0461 - auc: 0.6725 - mean_squared_error: 0.0130 - 76ms/epoch - 4ms/step
# Epoch 56/100
# 21/21 - 0s - loss: 0.0135 - Accuracy: 0.0461 - auc: 0.6752 - mean_squared_error: 0.0135 - 77ms/epoch - 4ms/step
# Epoch 57/100
# 21/21 - 0s - loss: 0.0125 - Accuracy: 0.0461 - auc: 0.6789 - mean_squared_error: 0.0125 - 79ms/epoch - 4ms/step
# Epoch 58/100
# 21/21 - 0s - loss: 0.0122 - Accuracy: 0.0461 - auc: 0.6802 - mean_squared_error: 0.0122 - 78ms/epoch - 4ms/step
# Epoch 59/100
# 21/21 - 0s - loss: 0.0120 - Accuracy: 0.0461 - auc: 0.6729 - mean_squared_error: 0.0120 - 75ms/epoch - 4ms/step
# Epoch 60/100
# 21/21 - 0s - loss: 0.0131 - Accuracy: 0.0461 - auc: 0.6606 - mean_squared_error: 0.0131 - 78ms/epoch - 4ms/step
# Epoch 61/100
# 21/21 - 0s - loss: 0.0133 - Accuracy: 0.0461 - auc: 0.6944 - mean_squared_error: 0.0133 - 76ms/epoch - 4ms/step
# Epoch 62/100
# 21/21 - 0s - loss: 0.0119 - Accuracy: 0.0461 - auc: 0.6256 - mean_squared_error: 0.0119 - 77ms/epoch - 4ms/step
# Epoch 63/100
# 21/21 - 0s - loss: 0.0131 - Accuracy: 0.0461 - auc: 0.7621 - mean_squared_error: 0.0131 - 76ms/epoch - 4ms/step
# Epoch 64/100
# 21/21 - 0s - loss: 0.0118 - Accuracy: 0.0461 - auc: 0.6338 - mean_squared_error: 0.0118 - 77ms/epoch - 4ms/step
# Epoch 65/100
# 21/21 - 0s - loss: 0.0126 - Accuracy: 0.0461 - auc: 0.7118 - mean_squared_error: 0.0126 - 75ms/epoch - 4ms/step
# Epoch 66/100
# 21/21 - 0s - loss: 0.0122 - Accuracy: 0.0461 - auc: 0.6641 - mean_squared_error: 0.0122 - 76ms/epoch - 4ms/step
# Epoch 67/100
# 21/21 - 0s - loss: 0.0119 - Accuracy: 0.0461 - auc: 0.7012 - mean_squared_error: 0.0119 - 76ms/epoch - 4ms/step
# Epoch 68/100
# 21/21 - 0s - loss: 0.0122 - Accuracy: 0.0461 - auc: 0.6826 - mean_squared_error: 0.0122 - 75ms/epoch - 4ms/step
# Epoch 69/100
# 21/21 - 0s - loss: 0.0116 - Accuracy: 0.0461 - auc: 0.7258 - mean_squared_error: 0.0116 - 76ms/epoch - 4ms/step
# Epoch 70/100
# 21/21 - 0s - loss: 0.0117 - Accuracy: 0.0461 - auc: 0.7291 - mean_squared_error: 0.0117 - 76ms/epoch - 4ms/step
# Epoch 71/100
# 21/21 - 0s - loss: 0.0126 - Accuracy: 0.0461 - auc: 0.6854 - mean_squared_error: 0.0126 - 76ms/epoch - 4ms/step
# Epoch 72/100
# 21/21 - 0s - loss: 0.0124 - Accuracy: 0.0461 - auc: 0.6582 - mean_squared_error: 0.0124 - 80ms/epoch - 4ms/step
# Epoch 73/100
# 21/21 - 0s - loss: 0.0121 - Accuracy: 0.0461 - auc: 0.6746 - mean_squared_error: 0.0121 - 78ms/epoch - 4ms/step
# Epoch 74/100
# 21/21 - 0s - loss: 0.0118 - Accuracy: 0.0461 - auc: 0.6787 - mean_squared_error: 0.0118 - 76ms/epoch - 4ms/step
# Epoch 75/100
# 21/21 - 0s - loss: 0.0110 - Accuracy: 0.0461 - auc: 0.6783 - mean_squared_error: 0.0110 - 75ms/epoch - 4ms/step
# Epoch 76/100
# 21/21 - 0s - loss: 0.0121 - Accuracy: 0.0461 - auc: 0.6879 - mean_squared_error: 0.0121 - 76ms/epoch - 4ms/step
# Epoch 77/100
# 21/21 - 0s - loss: 0.0115 - Accuracy: 0.0461 - auc: 0.6821 - mean_squared_error: 0.0115 - 77ms/epoch - 4ms/step
# Epoch 78/100
# 21/21 - 0s - loss: 0.0121 - Accuracy: 0.0461 - auc: 0.6849 - mean_squared_error: 0.0121 - 80ms/epoch - 4ms/step
# Epoch 79/100
# 21/21 - 0s - loss: 0.0123 - Accuracy: 0.0461 - auc: 0.6672 - mean_squared_error: 0.0123 - 79ms/epoch - 4ms/step
# Epoch 80/100
# 21/21 - 0s - loss: 0.0128 - Accuracy: 0.0445 - auc: 0.7189 - mean_squared_error: 0.0128 - 76ms/epoch - 4ms/step
# Epoch 81/100
# 21/21 - 0s - loss: 0.0113 - Accuracy: 0.0461 - auc: 0.7138 - mean_squared_error: 0.0113 - 79ms/epoch - 4ms/step
# Epoch 82/100
# 21/21 - 0s - loss: 0.0126 - Accuracy: 0.0461 - auc: 0.6800 - mean_squared_error: 0.0126 - 76ms/epoch - 4ms/step
# Epoch 83/100
# 21/21 - 0s - loss: 0.0127 - Accuracy: 0.0461 - auc: 0.6846 - mean_squared_error: 0.0127 - 76ms/epoch - 4ms/step
# Epoch 84/100
# 21/21 - 0s - loss: 0.0107 - Accuracy: 0.0461 - auc: 0.6892 - mean_squared_error: 0.0107 - 76ms/epoch - 4ms/step
# Epoch 85/100
# 21/21 - 0s - loss: 0.0132 - Accuracy: 0.0461 - auc: 0.6482 - mean_squared_error: 0.0132 - 75ms/epoch - 4ms/step
# Epoch 86/100
# 21/21 - 0s - loss: 0.0112 - Accuracy: 0.0461 - auc: 0.6733 - mean_squared_error: 0.0112 - 80ms/epoch - 4ms/step
# Epoch 87/100
# 21/21 - 0s - loss: 0.0113 - Accuracy: 0.0461 - auc: 0.7256 - mean_squared_error: 0.0113 - 76ms/epoch - 4ms/step
# Epoch 88/100
# 21/21 - 0s - loss: 0.0114 - Accuracy: 0.0461 - auc: 0.6766 - mean_squared_error: 0.0114 - 77ms/epoch - 4ms/step
# Epoch 89/100
# 21/21 - 0s - loss: 0.0103 - Accuracy: 0.0461 - auc: 0.7062 - mean_squared_error: 0.0103 - 78ms/epoch - 4ms/step
# Epoch 90/100
# 21/21 - 0s - loss: 0.0111 - Accuracy: 0.0461 - auc: 0.6684 - mean_squared_error: 0.0111 - 76ms/epoch - 4ms/step
# Epoch 91/100
# 21/21 - 0s - loss: 0.0105 - Accuracy: 0.0461 - auc: 0.6478 - mean_squared_error: 0.0105 - 75ms/epoch - 4ms/step
# Epoch 92/100
# 21/21 - 0s - loss: 0.0115 - Accuracy: 0.0461 - auc: 0.7247 - mean_squared_error: 0.0115 - 75ms/epoch - 4ms/step
# Epoch 93/100
# 21/21 - 0s - loss: 0.0112 - Accuracy: 0.0461 - auc: 0.6941 - mean_squared_error: 0.0112 - 76ms/epoch - 4ms/step
# Epoch 94/100
# 21/21 - 0s - loss: 0.0120 - Accuracy: 0.0461 - auc: 0.6728 - mean_squared_error: 0.0120 - 75ms/epoch - 4ms/step
# Epoch 95/100
# 21/21 - 0s - loss: 0.0114 - Accuracy: 0.0461 - auc: 0.6875 - mean_squared_error: 0.0114 - 76ms/epoch - 4ms/step
# Epoch 96/100
# 21/21 - 0s - loss: 0.0117 - Accuracy: 0.0461 - auc: 0.6723 - mean_squared_error: 0.0117 - 75ms/epoch - 4ms/step
# Epoch 97/100
# 21/21 - 0s - loss: 0.0117 - Accuracy: 0.0461 - auc: 0.6745 - mean_squared_error: 0.0117 - 75ms/epoch - 4ms/step
# Epoch 98/100
# 21/21 - 0s - loss: 0.0125 - Accuracy: 0.0461 - auc: 0.6604 - mean_squared_error: 0.0125 - 75ms/epoch - 4ms/step
# Epoch 99/100
# 21/21 - 0s - loss: 0.0107 - Accuracy: 0.0461 - auc: 0.6888 - mean_squared_error: 0.0107 - 76ms/epoch - 4ms/step
# Epoch 100/100
# 21/21 - 0s - loss: 0.0116 - Accuracy: 0.0461 - auc: 0.7193 - mean_squared_error: 0.0116 - 75ms/epoch - 4ms/step
# 9/9 [==============================] - 1s 2ms/step
# (261, 1, 1)

# %%
'''
X_train = X_train.values
X_train = X_train.reshape(X_train.shape[0], 1, X_train.shape[1])
X_test = X_test.values
X_test = X_test.reshape(X_test.shape[0], 1, X_test.shape[1])
model = attnnk(31, 32, 31, X_train.shape)
X_train = tf.data.Dataset.from_tensor_slices((X_train, Y_train))
X_test = tf.data.Dataset.from_tensor_slices((X_test, Y_test))
X_train = X_train.batch(batch)
X_test = X_test.batch(batch)
#model = attnnk(31, 64, 31, X_train.shape)
history = model.fit(X_train, epochs=epoch)
results = model.evaluate(X_test)'''

# %%
model2 = keras.models.Sequential([keras.layers.SimpleRNN(100, activation = 'relu'), keras.layers.Dense(1)])
model2.compile(optimizer = 'adam', loss = 'mse', metrics = ['Accuracy', 'AUC', 'MeanSquaredError'])
history = model2.fit(X_train, y_train, epochs=100, validation_split=0.3, verbose=2)
# Out:
# Epoch 1/100
# 14/14 - 1s - loss: 0.0668 - Accuracy: 0.0401 - auc: 0.6705 - mean_squared_error: 0.0668 - val_loss: 0.0389 - val_Accuracy: 0.0546 - val_auc: 0.4477 - val_mean_squared_error: 0.0389 - 1s/epoch - 104ms/step
# Epoch 2/100
# 14/14 - 0s - loss: 0.0391 - Accuracy: 0.0425 - auc: 0.6067 - mean_squared_error: 0.0391 - val_loss: 0.0177 - val_Accuracy: 0.0546 - val_auc: 0.4650 - val_mean_squared_error: 0.0177 - 52ms/epoch - 4ms/step
# Epoch 3/100
# 14/14 - 0s - loss: 0.0266 - Accuracy: 0.0401 - auc: 0.6868 - mean_squared_error: 0.0266 - val_loss: 0.0146 - val_Accuracy: 0.0546 - val_auc: 0.5040 - val_mean_squared_error: 0.0146 - 55ms/epoch - 4ms/step
# Epoch 4/100
# 14/14 - 0s - loss: 0.0221 - Accuracy: 0.0425 - auc: 0.7286 - mean_squared_error: 0.0221 - val_loss: 0.0144 - val_Accuracy: 0.0546 - val_auc: 0.4723 - val_mean_squared_error: 0.0144 - 52ms/epoch - 4ms/step
# Epoch 5/100
# 14/14 - 0s - loss: 0.0199 - Accuracy: 0.0425 - auc: 0.7595 - mean_squared_error: 0.0199 - val_loss: 0.0133 - val_Accuracy: 0.0546 - val_auc: 0.5003 - val_mean_squared_error: 0.0133 - 69ms/epoch - 5ms/step
# Epoch 6/100
# 14/14 - 0s - loss: 0.0193 - Accuracy: 0.0425 - auc: 0.7865 - mean_squared_error: 0.0193 - val_loss: 0.0133 - val_Accuracy: 0.0546 - val_auc: 0.5029 - val_mean_squared_error: 0.0133 - 50ms/epoch - 4ms/step
# Epoch 7/100
# 14/14 - 0s - loss: 0.0182 - Accuracy: 0.0425 - auc: 0.8110 - mean_squared_error: 0.0182 - val_loss: 0.0131 - val_Accuracy: 0.0546 - val_auc: 0.5150 - val_mean_squared_error: 0.0131 - 55ms/epoch - 4ms/step
# Epoch 8/100
# 14/14 - 0s - loss: 0.0178 - Accuracy: 0.0425 - auc: 0.8248 - mean_squared_error: 0.0178 - val_loss: 0.0128 - val_Accuracy: 0.0546 - val_auc: 0.5156 - val_mean_squared_error: 0.0128 - 51ms/epoch - 4ms/step
# Epoch 9/100
# 14/14 - 0s - loss: 0.0174 - Accuracy: 0.0425 - auc: 0.8318 - mean_squared_error: 0.0174 - val_loss: 0.0125 - val_Accuracy: 0.0546 - val_auc: 0.5347 - val_mean_squared_error: 0.0125 - 51ms/epoch - 4ms/step
# Epoch 10/100
# 14/14 - 0s - loss: 0.0167 - Accuracy: 0.0425 - auc: 0.8420 - mean_squared_error: 0.0167 - val_loss: 0.0126 - val_Accuracy: 0.0546 - val_auc: 0.5145 - val_mean_squared_error: 0.0126 - 49ms/epoch - 4ms/step
# Epoch 11/100
# 14/14 - 0s - loss: 0.0164 - Accuracy: 0.0425 - auc: 0.8571 - mean_squared_error: 0.0164 - val_loss: 0.0123 - val_Accuracy: 0.0546 - val_auc: 0.5121 - val_mean_squared_error: 0.0123 - 51ms/epoch - 4ms/step
# Epoch 12/100
# 14/14 - 0s - loss: 0.0161 - Accuracy: 0.0425 - auc: 0.8429 - mean_squared_error: 0.0161 - val_loss: 0.0120 - val_Accuracy: 0.0546 - val_auc: 0.5188 - val_mean_squared_error: 0.0120 - 50ms/epoch - 4ms/step
# Epoch 13/100
# 14/14 - 0s - loss: 0.0168 - Accuracy: 0.0425 - auc: 0.8647 - mean_squared_error: 0.0168 - val_loss: 0.0131 - val_Accuracy: 0.0546 - val_auc: 0.5280 - val_mean_squared_error: 0.0131 - 60ms/epoch - 4ms/step
# Epoch 14/100
# 14/14 - 0s - loss: 0.0165 - Accuracy: 0.0425 - auc: 0.7692 - mean_squared_error: 0.0165 - val_loss: 0.0121 - val_Accuracy: 0.0546 - val_auc: 0.5517 - val_mean_squared_error: 0.0121 - 53ms/epoch - 4ms/step
# Epoch 15/100
# 14/14 - 0s - loss: 0.0154 - Accuracy: 0.0425 - auc: 0.8884 - mean_squared_error: 0.0154 - val_loss: 0.0120 - val_Accuracy: 0.0546 - val_auc: 0.5367 - val_mean_squared_error: 0.0120 - 51ms/epoch - 4ms/step
# Epoch 16/100
# 14/14 - 0s - loss: 0.0151 - Accuracy: 0.0425 - auc: 0.8383 - mean_squared_error: 0.0151 - val_loss: 0.0117 - val_Accuracy: 0.0546 - val_auc: 0.5566 - val_mean_squared_error: 0.0117 - 56ms/epoch - 4ms/step
# Epoch 17/100
# 14/14 - 0s - loss: 0.0153 - Accuracy: 0.0425 - auc: 0.8301 - mean_squared_error: 0.0153 - val_loss: 0.0116 - val_Accuracy: 0.0546 - val_auc: 0.5601 - val_mean_squared_error: 0.0116 - 52ms/epoch - 4ms/step
# Epoch 18/100
# 14/14 - 0s - loss: 0.0149 - Accuracy: 0.0425 - auc: 0.8451 - mean_squared_error: 0.0149 - val_loss: 0.0116 - val_Accuracy: 0.0546 - val_auc: 0.5399 - val_mean_squared_error: 0.0116 - 55ms/epoch - 4ms/step
# Epoch 19/100
# 14/14 - 0s - loss: 0.0147 - Accuracy: 0.0425 - auc: 0.8546 - mean_squared_error: 0.0147 - val_loss: 0.0115 - val_Accuracy: 0.0546 - val_auc: 0.5581 - val_mean_squared_error: 0.0115 - 53ms/epoch - 4ms/step
# Epoch 20/100
# 14/14 - 0s - loss: 0.0144 - Accuracy: 0.0425 - auc: 0.8451 - mean_squared_error: 0.0144 - val_loss: 0.0116 - val_Accuracy: 0.0546 - val_auc: 0.5858 - val_mean_squared_error: 0.0116 - 50ms/epoch - 4ms/step
# Epoch 21/100
# 14/14 - 0s - loss: 0.0143 - Accuracy: 0.0425 - auc: 0.8458 - mean_squared_error: 0.0143 - val_loss: 0.0118 - val_Accuracy: 0.0546 - val_auc: 0.5653 - val_mean_squared_error: 0.0118 - 57ms/epoch - 4ms/step
# Epoch 22/100
# 14/14 - 0s - loss: 0.0144 - Accuracy: 0.0425 - auc: 0.8342 - mean_squared_error: 0.0144 - val_loss: 0.0124 - val_Accuracy: 0.0546 - val_auc: 0.5324 - val_mean_squared_error: 0.0124 - 52ms/epoch - 4ms/step
# Epoch 23/100
# 14/14 - 0s - loss: 0.0145 - Accuracy: 0.0425 - auc: 0.8253 - mean_squared_error: 0.0145 - val_loss: 0.0116 - val_Accuracy: 0.0546 - val_auc: 0.5916 - val_mean_squared_error: 0.0116 - 51ms/epoch - 4ms/step
# Epoch 24/100
# 14/14 - 0s - loss: 0.0143 - Accuracy: 0.0425 - auc: 0.8123 - mean_squared_error: 0.0143 - val_loss: 0.0118 - val_Accuracy: 0.0546 - val_auc: 0.5968 - val_mean_squared_error: 0.0118 - 84ms/epoch - 6ms/step
# Epoch 25/100
# 14/14 - 0s - loss: 0.0146 - Accuracy: 0.0425 - auc: 0.8465 - mean_squared_error: 0.0146 - val_loss: 0.0125 - val_Accuracy: 0.0546 - val_auc: 0.5801 - val_mean_squared_error: 0.0125 - 67ms/epoch - 5ms/step
# Epoch 26/100
# 14/14 - 0s - loss: 0.0139 - Accuracy: 0.0425 - auc: 0.7961 - mean_squared_error: 0.0139 - val_loss: 0.0114 - val_Accuracy: 0.0546 - val_auc: 0.6081 - val_mean_squared_error: 0.0114 - 60ms/epoch - 4ms/step
# Epoch 27/100
# 14/14 - 0s - loss: 0.0144 - Accuracy: 0.0425 - auc: 0.8343 - mean_squared_error: 0.0144 - val_loss: 0.0118 - val_Accuracy: 0.0546 - val_auc: 0.6032 - val_mean_squared_error: 0.0118 - 61ms/epoch - 4ms/step
# Epoch 28/100
# 14/14 - 0s - loss: 0.0139 - Accuracy: 0.0425 - auc: 0.8579 - mean_squared_error: 0.0139 - val_loss: 0.0118 - val_Accuracy: 0.0546 - val_auc: 0.6020 - val_mean_squared_error: 0.0118 - 55ms/epoch - 4ms/step
# Epoch 29/100
# 14/14 - 0s - loss: 0.0137 - Accuracy: 0.0425 - auc: 0.8067 - mean_squared_error: 0.0137 - val_loss: 0.0113 - val_Accuracy: 0.0546 - val_auc: 0.5945 - val_mean_squared_error: 0.0113 - 56ms/epoch - 4ms/step
# Epoch 30/100
# 14/14 - 0s - loss: 0.0134 - Accuracy: 0.0425 - auc: 0.8428 - mean_squared_error: 0.0134 - val_loss: 0.0117 - val_Accuracy: 0.0546 - val_auc: 0.5876 - val_mean_squared_error: 0.0117 - 52ms/epoch - 4ms/step
# Epoch 31/100
# 14/14 - 0s - loss: 0.0133 - Accuracy: 0.0425 - auc: 0.8349 - mean_squared_error: 0.0133 - val_loss: 0.0113 - val_Accuracy: 0.0546 - val_auc: 0.6066 - val_mean_squared_error: 0.0113 - 50ms/epoch - 4ms/step
# Epoch 32/100
# 14/14 - 0s - loss: 0.0132 - Accuracy: 0.0425 - auc: 0.8302 - mean_squared_error: 0.0132 - val_loss: 0.0116 - val_Accuracy: 0.0546 - val_auc: 0.5951 - val_mean_squared_error: 0.0116 - 51ms/epoch - 4ms/step
# Epoch 33/100
# 14/14 - 0s - loss: 0.0134 - Accuracy: 0.0425 - auc: 0.8257 - mean_squared_error: 0.0134 - val_loss: 0.0120 - val_Accuracy: 0.0546 - val_auc: 0.6113 - val_mean_squared_error: 0.0120 - 51ms/epoch - 4ms/step
# Epoch 34/100
# 14/14 - 0s - loss: 0.0138 - Accuracy: 0.0425 - auc: 0.8136 - mean_squared_error: 0.0138 - val_loss: 0.0121 - val_Accuracy: 0.0546 - val_auc: 0.6075 - val_mean_squared_error: 0.0121 - 51ms/epoch - 4ms/step
# Epoch 35/100
# 14/14 - 0s - loss: 0.0131 - Accuracy: 0.0425 - auc: 0.8255 - mean_squared_error: 0.0131 - val_loss: 0.0121 - val_Accuracy: 0.0546 - val_auc: 0.6243 - val_mean_squared_error: 0.0121 - 57ms/epoch - 4ms/step
# Epoch 36/100
# 14/14 - 0s - loss: 0.0136 - Accuracy: 0.0425 - auc: 0.8374 - mean_squared_error: 0.0136 - val_loss: 0.0122 - val_Accuracy: 0.0546 - val_auc: 0.6136 - val_mean_squared_error: 0.0122 - 51ms/epoch - 4ms/step
# Epoch 37/100
# 14/14 - 0s - loss: 0.0131 - Accuracy: 0.0425 - auc: 0.8214 - mean_squared_error: 0.0131 - val_loss: 0.0115 - val_Accuracy: 0.0546 - val_auc: 0.6095 - val_mean_squared_error: 0.0115 - 51ms/epoch - 4ms/step
# Epoch 38/100
# 14/14 - 0s - loss: 0.0127 - Accuracy: 0.0425 - auc: 0.8220 - mean_squared_error: 0.0127 - val_loss: 0.0114 - val_Accuracy: 0.0546 - val_auc: 0.6159 - val_mean_squared_error: 0.0114 - 52ms/epoch - 4ms/step
# Epoch 39/100
# 14/14 - 0s - loss: 0.0126 - Accuracy: 0.0425 - auc: 0.8337 - mean_squared_error: 0.0126 - val_loss: 0.0117 - val_Accuracy: 0.0546 - val_auc: 0.6113 - val_mean_squared_error: 0.0117 - 54ms/epoch - 4ms/step
# Epoch 40/100
# 14/14 - 0s - loss: 0.0128 - Accuracy: 0.0425 - auc: 0.8411 - mean_squared_error: 0.0128 - val_loss: 0.0121 - val_Accuracy: 0.0546 - val_auc: 0.6335 - val_mean_squared_error: 0.0121 - 52ms/epoch - 4ms/step
# Epoch 41/100
# 14/14 - 0s - loss: 0.0128 - Accuracy: 0.0425 - auc: 0.8422 - mean_squared_error: 0.0128 - val_loss: 0.0114 - val_Accuracy: 0.0546 - val_auc: 0.6127 - val_mean_squared_error: 0.0114 - 51ms/epoch - 4ms/step
# Epoch 42/100
# 14/14 - 0s - loss: 0.0124 - Accuracy: 0.0425 - auc: 0.8334 - mean_squared_error: 0.0124 - val_loss: 0.0119 - val_Accuracy: 0.0546 - val_auc: 0.6176 - val_mean_squared_error: 0.0119 - 55ms/epoch - 4ms/step
# Epoch 43/100
# 14/14 - 0s - loss: 0.0127 - Accuracy: 0.0425 - auc: 0.8128 - mean_squared_error: 0.0127 - val_loss: 0.0113 - val_Accuracy: 0.0546 - val_auc: 0.6303 - val_mean_squared_error: 0.0113 - 53ms/epoch - 4ms/step
# Epoch 44/100
# 14/14 - 0s - loss: 0.0124 - Accuracy: 0.0425 - auc: 0.8447 - mean_squared_error: 0.0124 - val_loss: 0.0114 - val_Accuracy: 0.0546 - val_auc: 0.6269 - val_mean_squared_error: 0.0114 - 53ms/epoch - 4ms/step
# Epoch 45/100
# 14/14 - 0s - loss: 0.0124 - Accuracy: 0.0425 - auc: 0.8443 - mean_squared_error: 0.0124 - val_loss: 0.0116 - val_Accuracy: 0.0546 - val_auc: 0.6234 - val_mean_squared_error: 0.0116 - 52ms/epoch - 4ms/step
# Epoch 46/100
# 14/14 - 0s - loss: 0.0126 - Accuracy: 0.0425 - auc: 0.8292 - mean_squared_error: 0.0126 - val_loss: 0.0116 - val_Accuracy: 0.0546 - val_auc: 0.6162 - val_mean_squared_error: 0.0116 - 53ms/epoch - 4ms/step
# Epoch 47/100
# 14/14 - 0s - loss: 0.0126 - Accuracy: 0.0425 - auc: 0.8300 - mean_squared_error: 0.0126 - val_loss: 0.0116 - val_Accuracy: 0.0546 - val_auc: 0.6321 - val_mean_squared_error: 0.0116 - 53ms/epoch - 4ms/step
# Epoch 48/100
# 14/14 - 0s - loss: 0.0124 - Accuracy: 0.0425 - auc: 0.8589 - mean_squared_error: 0.0124 - val_loss: 0.0116 - val_Accuracy: 0.0546 - val_auc: 0.6263 - val_mean_squared_error: 0.0116 - 60ms/epoch - 4ms/step
# Epoch 49/100
# 14/14 - 0s - loss: 0.0120 - Accuracy: 0.0425 - auc: 0.8402 - mean_squared_error: 0.0120 - val_loss: 0.0120 - val_Accuracy: 0.0546 - val_auc: 0.6231 - val_mean_squared_error: 0.0120 - 51ms/epoch - 4ms/step
# Epoch 50/100
# 14/14 - 0s - loss: 0.0124 - Accuracy: 0.0425 - auc: 0.8347 - mean_squared_error: 0.0124 - val_loss: 0.0117 - val_Accuracy: 0.0546 - val_auc: 0.6428 - val_mean_squared_error: 0.0117 - 52ms/epoch - 4ms/step
# Epoch 51/100
# 14/14 - 0s - loss: 0.0121 - Accuracy: 0.0425 - auc: 0.8223 - mean_squared_error: 0.0121 - val_loss: 0.0115 - val_Accuracy: 0.0546 - val_auc: 0.6254 - val_mean_squared_error: 0.0115 - 53ms/epoch - 4ms/step
# Epoch 52/100
# 14/14 - 0s - loss: 0.0122 - Accuracy: 0.0425 - auc: 0.8137 - mean_squared_error: 0.0122 - val_loss: 0.0115 - val_Accuracy: 0.0546 - val_auc: 0.6246 - val_mean_squared_error: 0.0115 - 51ms/epoch - 4ms/step
# Epoch 53/100
# 14/14 - 0s - loss: 0.0125 - Accuracy: 0.0425 - auc: 0.7954 - mean_squared_error: 0.0125 - val_loss: 0.0117 - val_Accuracy: 0.0546 - val_auc: 0.6272 - val_mean_squared_error: 0.0117 - 51ms/epoch - 4ms/step
# Epoch 54/100
# 14/14 - 0s - loss: 0.0124 - Accuracy: 0.0425 - auc: 0.8472 - mean_squared_error: 0.0124 - val_loss: 0.0113 - val_Accuracy: 0.0546 - val_auc: 0.6344 - val_mean_squared_error: 0.0113 - 56ms/epoch - 4ms/step
# Epoch 55/100
# 14/14 - 0s - loss: 0.0122 - Accuracy: 0.0425 - auc: 0.8253 - mean_squared_error: 0.0122 - val_loss: 0.0119 - val_Accuracy: 0.0546 - val_auc: 0.6350 - val_mean_squared_error: 0.0119 - 52ms/epoch - 4ms/step
# Epoch 56/100
# 14/14 - 0s - loss: 0.0122 - Accuracy: 0.0425 - auc: 0.8176 - mean_squared_error: 0.0122 - val_loss: 0.0113 - val_Accuracy: 0.0546 - val_auc: 0.6243 - val_mean_squared_error: 0.0113 - 54ms/epoch - 4ms/step
# Epoch 57/100
# 14/14 - 0s - loss: 0.0120 - Accuracy: 0.0425 - auc: 0.8296 - mean_squared_error: 0.0120 - val_loss: 0.0114 - val_Accuracy: 0.0546 - val_auc: 0.6292 - val_mean_squared_error: 0.0114 - 52ms/epoch - 4ms/step
# Epoch 58/100
# 14/14 - 0s - loss: 0.0117 - Accuracy: 0.0425 - auc: 0.8160 - mean_squared_error: 0.0117 - val_loss: 0.0117 - val_Accuracy: 0.0546 - val_auc: 0.6396 - val_mean_squared_error: 0.0117 - 52ms/epoch - 4ms/step
# Epoch 59/100
# 14/14 - 0s - loss: 0.0117 - Accuracy: 0.0425 - auc: 0.8256 - mean_squared_error: 0.0117 - val_loss: 0.0113 - val_Accuracy: 0.0546 - val_auc: 0.6353 - val_mean_squared_error: 0.0113 - 54ms/epoch - 4ms/step
# Epoch 60/100
# 14/14 - 0s - loss: 0.0118 - Accuracy: 0.0425 - auc: 0.8446 - mean_squared_error: 0.0118 - val_loss: 0.0122 - val_Accuracy: 0.0546 - val_auc: 0.6327 - val_mean_squared_error: 0.0122 - 52ms/epoch - 4ms/step
# Epoch 61/100
# 14/14 - 0s - loss: 0.0118 - Accuracy: 0.0425 - auc: 0.8626 - mean_squared_error: 0.0118 - val_loss: 0.0116 - val_Accuracy: 0.0546 - val_auc: 0.6364 - val_mean_squared_error: 0.0116 - 56ms/epoch - 4ms/step
# Epoch 62/100
# 14/14 - 0s - loss: 0.0117 - Accuracy: 0.0425 - auc: 0.8303 - mean_squared_error: 0.0117 - val_loss: 0.0115 - val_Accuracy: 0.0546 - val_auc: 0.6286 - val_mean_squared_error: 0.0115 - 58ms/epoch - 4ms/step
# Epoch 63/100
# 14/14 - 0s - loss: 0.0120 - Accuracy: 0.0425 - auc: 0.8230 - mean_squared_error: 0.0120 - val_loss: 0.0125 - val_Accuracy: 0.0546 - val_auc: 0.6277 - val_mean_squared_error: 0.0125 - 83ms/epoch - 6ms/step
# Epoch 64/100
# 14/14 - 0s - loss: 0.0118 - Accuracy: 0.0425 - auc: 0.7901 - mean_squared_error: 0.0118 - val_loss: 0.0112 - val_Accuracy: 0.0546 - val_auc: 0.6486 - val_mean_squared_error: 0.0112 - 69ms/epoch - 5ms/step
# Epoch 65/100
# 14/14 - 0s - loss: 0.0115 - Accuracy: 0.0425 - auc: 0.8321 - mean_squared_error: 0.0115 - val_loss: 0.0116 - val_Accuracy: 0.0546 - val_auc: 0.6350 - val_mean_squared_error: 0.0116 - 54ms/epoch - 4ms/step
# Epoch 66/100
# 14/14 - 0s - loss: 0.0115 - Accuracy: 0.0425 - auc: 0.8521 - mean_squared_error: 0.0115 - val_loss: 0.0113 - val_Accuracy: 0.0546 - val_auc: 0.6428 - val_mean_squared_error: 0.0113 - 63ms/epoch - 5ms/step
# Epoch 67/100
# 14/14 - 0s - loss: 0.0114 - Accuracy: 0.0425 - auc: 0.8404 - mean_squared_error: 0.0114 - val_loss: 0.0113 - val_Accuracy: 0.0546 - val_auc: 0.6491 - val_mean_squared_error: 0.0113 - 49ms/epoch - 4ms/step
# Epoch 68/100
# 14/14 - 0s - loss: 0.0114 - Accuracy: 0.0425 - auc: 0.8230 - mean_squared_error: 0.0114 - val_loss: 0.0119 - val_Accuracy: 0.0546 - val_auc: 0.6500 - val_mean_squared_error: 0.0119 - 52ms/epoch - 4ms/step
# Epoch 69/100
# 14/14 - 0s - loss: 0.0122 - Accuracy: 0.0425 - auc: 0.8093 - mean_squared_error: 0.0122 - val_loss: 0.0126 - val_Accuracy: 0.0546 - val_auc: 0.6361 - val_mean_squared_error: 0.0126 - 50ms/epoch - 4ms/step
# Epoch 70/100
# 14/14 - 0s - loss: 0.0111 - Accuracy: 0.0425 - auc: 0.8022 - mean_squared_error: 0.0111 - val_loss: 0.0112 - val_Accuracy: 0.0546 - val_auc: 0.6500 - val_mean_squared_error: 0.0112 - 53ms/epoch - 4ms/step
# Epoch 71/100
# 14/14 - 0s - loss: 0.0113 - Accuracy: 0.0425 - auc: 0.8476 - mean_squared_error: 0.0113 - val_loss: 0.0118 - val_Accuracy: 0.0546 - val_auc: 0.6153 - val_mean_squared_error: 0.0118 - 52ms/epoch - 4ms/step
# Epoch 72/100
# 14/14 - 0s - loss: 0.0113 - Accuracy: 0.0425 - auc: 0.8321 - mean_squared_error: 0.0113 - val_loss: 0.0113 - val_Accuracy: 0.0546 - val_auc: 0.6509 - val_mean_squared_error: 0.0113 - 50ms/epoch - 4ms/step
# Epoch 73/100
# 14/14 - 0s - loss: 0.0116 - Accuracy: 0.0425 - auc: 0.7921 - mean_squared_error: 0.0116 - val_loss: 0.0117 - val_Accuracy: 0.0546 - val_auc: 0.6434 - val_mean_squared_error: 0.0117 - 50ms/epoch - 4ms/step
# Epoch 74/100
# 14/14 - 0s - loss: 0.0115 - Accuracy: 0.0425 - auc: 0.8067 - mean_squared_error: 0.0115 - val_loss: 0.0118 - val_Accuracy: 0.0546 - val_auc: 0.6344 - val_mean_squared_error: 0.0118 - 52ms/epoch - 4ms/step
# Epoch 75/100
# 14/14 - 0s - loss: 0.0112 - Accuracy: 0.0425 - auc: 0.8367 - mean_squared_error: 0.0112 - val_loss: 0.0113 - val_Accuracy: 0.0546 - val_auc: 0.6543 - val_mean_squared_error: 0.0113 - 52ms/epoch - 4ms/step
# Epoch 76/100
# 14/14 - 0s - loss: 0.0121 - Accuracy: 0.0425 - auc: 0.7596 - mean_squared_error: 0.0121 - val_loss: 0.0122 - val_Accuracy: 0.0546 - val_auc: 0.6431 - val_mean_squared_error: 0.0122 - 52ms/epoch - 4ms/step
# Epoch 77/100
# 14/14 - 0s - loss: 0.0110 - Accuracy: 0.0425 - auc: 0.8348 - mean_squared_error: 0.0110 - val_loss: 0.0115 - val_Accuracy: 0.0546 - val_auc: 0.6572 - val_mean_squared_error: 0.0115 - 51ms/epoch - 4ms/step
# Epoch 78/100
# 14/14 - 0s - loss: 0.0110 - Accuracy: 0.0425 - auc: 0.8270 - mean_squared_error: 0.0110 - val_loss: 0.0112 - val_Accuracy: 0.0546 - val_auc: 0.6488 - val_mean_squared_error: 0.0112 - 49ms/epoch - 4ms/step
# Epoch 79/100
# 14/14 - 0s - loss: 0.0109 - Accuracy: 0.0425 - auc: 0.8289 - mean_squared_error: 0.0109 - val_loss: 0.0113 - val_Accuracy: 0.0546 - val_auc: 0.6451 - val_mean_squared_error: 0.0113 - 54ms/epoch - 4ms/step
# Epoch 80/100
# 14/14 - 0s - loss: 0.0111 - Accuracy: 0.0425 - auc: 0.8176 - mean_squared_error: 0.0111 - val_loss: 0.0112 - val_Accuracy: 0.0546 - val_auc: 0.6653 - val_mean_squared_error: 0.0112 - 51ms/epoch - 4ms/step
# Epoch 81/100
# 14/14 - 0s - loss: 0.0108 - Accuracy: 0.0425 - auc: 0.8229 - mean_squared_error: 0.0108 - val_loss: 0.0117 - val_Accuracy: 0.0546 - val_auc: 0.6486 - val_mean_squared_error: 0.0117 - 52ms/epoch - 4ms/step
# Epoch 82/100
# 14/14 - 0s - loss: 0.0112 - Accuracy: 0.0425 - auc: 0.7966 - mean_squared_error: 0.0112 - val_loss: 0.0123 - val_Accuracy: 0.0546 - val_auc: 0.6578 - val_mean_squared_error: 0.0123 - 51ms/epoch - 4ms/step
# Epoch 83/100
# 14/14 - 0s - loss: 0.0112 - Accuracy: 0.0425 - auc: 0.7849 - mean_squared_error: 0.0112 - val_loss: 0.0116 - val_Accuracy: 0.0546 - val_auc: 0.6572 - val_mean_squared_error: 0.0116 - 51ms/epoch - 4ms/step
# Epoch 84/100
# 14/14 - 0s - loss: 0.0114 - Accuracy: 0.0425 - auc: 0.8000 - mean_squared_error: 0.0114 - val_loss: 0.0117 - val_Accuracy: 0.0546 - val_auc: 0.6538 - val_mean_squared_error: 0.0117 - 51ms/epoch - 4ms/step
# Epoch 85/100
# 14/14 - 0s - loss: 0.0109 - Accuracy: 0.0425 - auc: 0.8170 - mean_squared_error: 0.0109 - val_loss: 0.0112 - val_Accuracy: 0.0546 - val_auc: 0.6572 - val_mean_squared_error: 0.0112 - 51ms/epoch - 4ms/step
# Epoch 86/100
# 14/14 - 0s - loss: 0.0110 - Accuracy: 0.0425 - auc: 0.8341 - mean_squared_error: 0.0110 - val_loss: 0.0116 - val_Accuracy: 0.0546 - val_auc: 0.6471 - val_mean_squared_error: 0.0116 - 51ms/epoch - 4ms/step
# Epoch 87/100
# 14/14 - 0s - loss: 0.0105 - Accuracy: 0.0425 - auc: 0.8453 - mean_squared_error: 0.0105 - val_loss: 0.0113 - val_Accuracy: 0.0546 - val_auc: 0.6572 - val_mean_squared_error: 0.0113 - 51ms/epoch - 4ms/step
# Epoch 88/100
# 14/14 - 0s - loss: 0.0108 - Accuracy: 0.0425 - auc: 0.8274 - mean_squared_error: 0.0108 - val_loss: 0.0117 - val_Accuracy: 0.0546 - val_auc: 0.6500 - val_mean_squared_error: 0.0117 - 51ms/epoch - 4ms/step
# Epoch 89/100
# 14/14 - 0s - loss: 0.0105 - Accuracy: 0.0425 - auc: 0.8404 - mean_squared_error: 0.0105 - val_loss: 0.0113 - val_Accuracy: 0.0546 - val_auc: 0.6581 - val_mean_squared_error: 0.0113 - 51ms/epoch - 4ms/step
# Epoch 90/100
# 14/14 - 0s - loss: 0.0104 - Accuracy: 0.0425 - auc: 0.8147 - mean_squared_error: 0.0104 - val_loss: 0.0119 - val_Accuracy: 0.0546 - val_auc: 0.6555 - val_mean_squared_error: 0.0119 - 54ms/epoch - 4ms/step
# Epoch 91/100
# 14/14 - 0s - loss: 0.0108 - Accuracy: 0.0425 - auc: 0.8032 - mean_squared_error: 0.0108 - val_loss: 0.0115 - val_Accuracy: 0.0546 - val_auc: 0.6613 - val_mean_squared_error: 0.0115 - 50ms/epoch - 4ms/step
# Epoch 92/100
# 14/14 - 0s - loss: 0.0107 - Accuracy: 0.0425 - auc: 0.8190 - mean_squared_error: 0.0107 - val_loss: 0.0115 - val_Accuracy: 0.0546 - val_auc: 0.6572 - val_mean_squared_error: 0.0115 - 50ms/epoch - 4ms/step
# Epoch 93/100
# 14/14 - 0s - loss: 0.0103 - Accuracy: 0.0425 - auc: 0.8300 - mean_squared_error: 0.0103 - val_loss: 0.0113 - val_Accuracy: 0.0546 - val_auc: 0.6535 - val_mean_squared_error: 0.0113 - 53ms/epoch - 4ms/step
# Epoch 94/100
# 14/14 - 0s - loss: 0.0102 - Accuracy: 0.0425 - auc: 0.8460 - mean_squared_error: 0.0102 - val_loss: 0.0136 - val_Accuracy: 0.0546 - val_auc: 0.6535 - val_mean_squared_error: 0.0136 - 54ms/epoch - 4ms/step
# Epoch 95/100
# 14/14 - 0s - loss: 0.0108 - Accuracy: 0.0425 - auc: 0.8430 - mean_squared_error: 0.0108 - val_loss: 0.0115 - val_Accuracy: 0.0546 - val_auc: 0.6618 - val_mean_squared_error: 0.0115 - 51ms/epoch - 4ms/step
# Epoch 96/100
# 14/14 - 0s - loss: 0.0107 - Accuracy: 0.0425 - auc: 0.8178 - mean_squared_error: 0.0107 - val_loss: 0.0123 - val_Accuracy: 0.0546 - val_auc: 0.6558 - val_mean_squared_error: 0.0123 - 55ms/epoch - 4ms/step
# Epoch 97/100
# 14/14 - 0s - loss: 0.0110 - Accuracy: 0.0425 - auc: 0.7966 - mean_squared_error: 0.0110 - val_loss: 0.0121 - val_Accuracy: 0.0546 - val_auc: 0.6506 - val_mean_squared_error: 0.0121 - 50ms/epoch - 4ms/step
# Epoch 98/100
# 14/14 - 0s - loss: 0.0107 - Accuracy: 0.0425 - auc: 0.8311 - mean_squared_error: 0.0107 - val_loss: 0.0113 - val_Accuracy: 0.0546 - val_auc: 0.6607 - val_mean_squared_error: 0.0113 - 52ms/epoch - 4ms/step
# Epoch 99/100
# 14/14 - 0s - loss: 0.0101 - Accuracy: 0.0425 - auc: 0.8276 - mean_squared_error: 0.0101 - val_loss: 0.0116 - val_Accuracy: 0.0546 - val_auc: 0.6468 - val_mean_squared_error: 0.0116 - 52ms/epoch - 4ms/step
# Epoch 100/100
# 14/14 - 0s - loss: 0.0101 - Accuracy: 0.0425 - auc: 0.8211 - mean_squared_error: 0.0101 - val_loss: 0.0121 - val_Accuracy: 0.0546 - val_auc: 0.6601 - val_mean_squared_error: 0.0121 - 52ms/epoch - 4ms/step

# %%
pred = model2.predict(X_test)
print(pred.shape)
att_pred = tf.squeeze(att_pred).numpy().reshape(-1,1)
att_pred = scaler_y.inverse_transform(att_pred)
pred = scaler_y.inverse_transform(pred)

y_test = scaler_y.inverse_transform(y_test)
# Out:
# 9/9 [==============================] - 0s 875us/step
# (261, 1)

# %%
plt.figure(figsize=(10, 6))
plt.plot(y_test, label='Actual')
plt.plot(att_pred, label='Predicted', alpha=0.7)
plt.title('Attention Actual vs Predicted Total Disasters')
plt.xlabel('Test Sample')
plt.ylabel('Total Disasters')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(y_test, label='Actual')
plt.plot(pred, label='Predicted', alpha=0.7)
plt.title('RNNActual vs Predicted Total Disasters')
plt.xlabel('Test Sample')
plt.ylabel('Total Disasters')
plt.legend()
plt.show()
