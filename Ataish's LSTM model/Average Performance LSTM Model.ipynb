# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense
from sklearn.model_selection import train_test_split

# %%
# Load dataset
file_path = "C:/Users/ATAISH NEHRA/Downloads/merged_natural_disaster_dataset_1992_2020.csv"  
data = pd.read_csv(file_path)

# %%
data
# Out:
#          Country  Year  Temperature  Drought  Extreme temperature  Flood  \
# 0    Afghanistan  1992       -0.294        0                    0      2
# 1    Afghanistan  1993        0.220        0                    0      0
# 2    Afghanistan  1994        0.430        0                    0      0
# 3    Afghanistan  1995        0.359        0                    0      2
# 4    Afghanistan  1996       -0.116        0                    0      1
# ..           ...   ...          ...      ...                  ...    ...
# 894        World  2016        1.660       14                   12    159
# 895        World  2017        1.429       12                   10    127
# 896        World  2018        1.290       17                   27    127
# 897        World  2019        1.444       15                   21    195
# 898        World  2020        1.711       12                    5    201
#
#      Landslide  Storm  Total Disasters  Wildfire  ...  \
# 0            0      0                2         0  ...
# 1            2      1                3         0  ...
# 2            0      0                0         0  ...
# 3            1      0                3         0  ...
# 4            0      0                1         0  ...
# ..         ...    ...              ...       ...  ...
# 894         13     86               10        10  ...
# 895         25    126               15        15  ...
# 896         12     94               10        10  ...
# 897         25     91               14        14  ...
# 898         19    127                9         9  ...
#
#      Sparsely natural vegetated areas: Climate neutral  \
# 0                                           4275.25530
# 1                                           4275.22430
# 2                                           4275.22430
# 3                                           4227.85360
# 4                                           4220.79300
# ..                                                 ...
# 894                                        21094.61677
# 895                                        21073.52536
# 896                                        20898.69670
# 897                                        20888.64099
# 898                                        20850.34855
#
#      Terrestrial barren land: Climate neutral  \
# 0                                 24963.00090
# 1                                 24963.00090
# 2                                 24963.00090
# 3                                 25088.57510
# 4                                 25108.35560
# ..                                        ...
# 894                               15707.56873
# 895                               15697.08307
# 896                               15679.27079
# 897                               15658.86106
# 898                               15637.17033
#
#      Tree-covered areas: Climate regulating  Woody crops: Climate regulating  \
# 0                                1263.70310                        87.433900
# 1                                1263.78800                        81.110900
# 2                                1263.86200                        82.360600
# 3                                1241.12490                        75.512400
# 4                                1240.81720                        79.485700
# ..                                      ...                              ...
# 894                             99041.46252                      4687.315517
# 895                             99039.17884                      4616.848180
# 896                             98704.85685                      4636.315717
# 897                             98385.52924                      4662.655917
# 898                             98355.54635                      4663.343037
#
#      Carbon stocks in forests  Forest area  Index of carbon stocks in forests  \
# 0                 2120.071125     1208.440                         100.000000
# 1                 2160.349425     1208.440                         101.072442
# 2                 2200.627750     1208.440                         102.144893
# 3                 2240.906000     1208.440                         103.217332
# 4                 2281.184300     1208.440                         104.289774
# ..                        ...          ...                                ...
# 894             294750.681000  4080599.782                          99.259755
# 895             294474.016900  4073753.425                          99.166586
# 896             294450.303600  4068919.514                          99.158601
# 897             294295.808000  4063839.320                          99.106573
# 898             294135.623400  4058927.050                          99.052629
#
#      Index of forest extent    Land area  Share of forest area
# 0                100.000000     65223.00              1.852782
# 1                100.000000     65223.00              1.852782
# 2                100.000000     65223.00              1.852782
# 3                100.000000     65223.00              1.852782
# 4                100.000000     65223.00              1.852782
# ..                      ...          ...                   ...
# 894               96.679343  13026958.88             31.324270
# 895               96.517136  13026230.26             31.273464
# 896               96.402609  13026300.91             31.236186
# 897               96.282247  13026294.74             31.197201
# 898               96.165863  13026238.97             31.159624
#
# [899 rows x 30 columns]

# %%
data.columns.values.tolist()
# Out:
# ['Country',
#  'Year',
#  'Temperature',
#  'Drought',
#  'Extreme temperature',
#  'Flood',
#  'Landslide',
#  'Storm',
#  'Total Disasters',
#  'Wildfire',
#  'Sea level Value',
#  'Artificial surfaces (including urban and associated areas): Climate altering',
#  'Cover Index: Climate altering',
#  'Grassland: Climate regulating',
#  'Herbaceous crops: Climate altering',
#  'Inland water bodies: Climate regulating',
#  'Mangroves: Climate regulating',
#  'Permanent snow and glaciers: Climate regulating',
#  'Shrub-covered areas: Climate regulating',
#  'Shrubs and/or herbaceous vegetation, aquatic or regularly flooded: Climate regulating',
#  'Sparsely natural vegetated areas: Climate neutral',
#  'Terrestrial barren land: Climate neutral',
#  'Tree-covered areas: Climate regulating',
#  'Woody crops: Climate regulating',
#  'Carbon stocks in forests',
#  'Forest area',
#  'Index of carbon stocks in forests',
#  'Index of forest extent',
#  'Land area',
#  'Share of forest area']

# %%
# Assuming 'Country', 'Year', and other feature columns are in the dataset
feature_columns = ['Temperature', 'Drought', 'Extreme temperature', 'Flood', 'Landslide', 'Storm', 'Wildfire', 'Forest area', 'Carbon stocks in forests']
target_column = 'Total Disasters'

# Scale the features
scaler_X = MinMaxScaler(feature_range=(0, 1))
X_scaled = scaler_X.fit_transform(data[feature_columns])

# Scale the target
scaler_y = MinMaxScaler(feature_range=(0, 1))
y_scaled = scaler_y.fit_transform(data[[target_column]])

# %%
# Assuming 'Country', 'Year', and other feature columns are in the dataset
feature_columns = ['Temperature', 'Sea level Value', 'Carbon stocks in forests', 'Sea level Value',
 'Artificial surfaces (including urban and associated areas): Climate altering',
 'Cover Index: Climate altering',
 'Grassland: Climate regulating',
 'Herbaceous crops: Climate altering',
 'Inland water bodies: Climate regulating',
 'Mangroves: Climate regulating',
 'Permanent snow and glaciers: Climate regulating',
 'Shrub-covered areas: Climate regulating',
 'Shrubs and/or herbaceous vegetation, aquatic or regularly flooded: Climate regulating',
 'Sparsely natural vegetated areas: Climate neutral',
 'Terrestrial barren land: Climate neutral',
 'Tree-covered areas: Climate regulating',
 'Woody crops: Climate regulating']
target_column = 'Total Disasters'

# Scale the features
scaler_X = MinMaxScaler(feature_range=(0, 1))
X_scaled = scaler_X.fit_transform(data[feature_columns])

# Scale the target
scaler_y = MinMaxScaler(feature_range=(0, 1))
y_scaled = scaler_y.fit_transform(data[[target_column]])

# %%
# Function to create sequences by country
def create_sequences_by_country(X, y, n_steps, data):
    Xs, ys = [], []
    countries = data['Country'].unique()
    for country in countries:
        country_indices = data[data['Country'] == country].index
        country_data_X = X[country_indices]
        country_data_y = y[country_indices]
        for i in range(len(country_data_X) - n_steps):
            Xs.append(country_data_X[i:(i + n_steps)])
            ys.append(country_data_y[i + n_steps])
    return np.array(Xs), np.array(ys).reshape(-1, 1)

n_steps = 3  # Using 3 years of data to predict the next year
X_seq, y_seq = create_sequences_by_country(X_scaled, y_scaled, n_steps, data)

# Split the dataset into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X_seq, y_seq, test_size=0.3, random_state=42)

# %%
# Define LSTM model
model = Sequential([
    LSTM(100, activation='relu', input_shape=(n_steps, len(feature_columns))),
    Dense(1)
])
model.compile(optimizer='adam', loss='mse')

# %%
# Train the model
history = model.fit(X_train, y_train, epochs=300, validation_split=0.3, verbose=2)
# Out:
# Epoch 1/300
# 13/13 - 0s - loss: 0.0014 - val_loss: 0.0178 - 74ms/epoch - 6ms/step
# Epoch 2/300
# 13/13 - 0s - loss: 0.0014 - val_loss: 0.0184 - 57ms/epoch - 4ms/step
# Epoch 3/300
# 13/13 - 0s - loss: 0.0015 - val_loss: 0.0183 - 53ms/epoch - 4ms/step
# Epoch 4/300
# 13/13 - 0s - loss: 0.0013 - val_loss: 0.0170 - 51ms/epoch - 4ms/step
# Epoch 5/300
# 13/13 - 0s - loss: 0.0015 - val_loss: 0.0188 - 53ms/epoch - 4ms/step
# Epoch 6/300
# 13/13 - 0s - loss: 0.0016 - val_loss: 0.0172 - 58ms/epoch - 4ms/step
# Epoch 7/300
# 13/13 - 0s - loss: 0.0013 - val_loss: 0.0169 - 52ms/epoch - 4ms/step
# Epoch 8/300
# 13/13 - 0s - loss: 0.0014 - val_loss: 0.0179 - 44ms/epoch - 3ms/step
# Epoch 9/300
# 13/13 - 0s - loss: 0.0015 - val_loss: 0.0184 - 46ms/epoch - 4ms/step
# Epoch 10/300
# 13/13 - 0s - loss: 0.0014 - val_loss: 0.0172 - 45ms/epoch - 3ms/step
# Epoch 11/300
# 13/13 - 0s - loss: 0.0016 - val_loss: 0.0182 - 44ms/epoch - 3ms/step
# Epoch 12/300
# 13/13 - 0s - loss: 0.0017 - val_loss: 0.0171 - 47ms/epoch - 4ms/step
# Epoch 13/300
# 13/13 - 0s - loss: 0.0014 - val_loss: 0.0190 - 46ms/epoch - 4ms/step
# Epoch 14/300
# 13/13 - 0s - loss: 0.0014 - val_loss: 0.0174 - 44ms/epoch - 3ms/step
# Epoch 15/300
# 13/13 - 0s - loss: 0.0013 - val_loss: 0.0181 - 44ms/epoch - 3ms/step
# Epoch 16/300
# 13/13 - 0s - loss: 0.0015 - val_loss: 0.0187 - 43ms/epoch - 3ms/step
# Epoch 17/300
# 13/13 - 0s - loss: 0.0015 - val_loss: 0.0166 - 47ms/epoch - 4ms/step
# Epoch 18/300
# 13/13 - 0s - loss: 0.0014 - val_loss: 0.0182 - 44ms/epoch - 3ms/step
# Epoch 19/300
# 13/13 - 0s - loss: 0.0013 - val_loss: 0.0179 - 44ms/epoch - 3ms/step
# Epoch 20/300
# 13/13 - 0s - loss: 0.0013 - val_loss: 0.0170 - 44ms/epoch - 3ms/step
# Epoch 21/300
# 13/13 - 0s - loss: 0.0014 - val_loss: 0.0186 - 50ms/epoch - 4ms/step
# Epoch 22/300
# 13/13 - 0s - loss: 0.0013 - val_loss: 0.0169 - 44ms/epoch - 3ms/step
# Epoch 23/300
# 13/13 - 0s - loss: 0.0016 - val_loss: 0.0180 - 49ms/epoch - 4ms/step
# Epoch 24/300
# 13/13 - 0s - loss: 0.0014 - val_loss: 0.0174 - 48ms/epoch - 4ms/step
# Epoch 25/300
# 13/13 - 0s - loss: 0.0015 - val_loss: 0.0179 - 43ms/epoch - 3ms/step
# Epoch 26/300
# 13/13 - 0s - loss: 0.0014 - val_loss: 0.0173 - 46ms/epoch - 4ms/step
# Epoch 27/300
# 13/13 - 0s - loss: 0.0014 - val_loss: 0.0184 - 43ms/epoch - 3ms/step
# Epoch 28/300
# 13/13 - 0s - loss: 0.0012 - val_loss: 0.0180 - 48ms/epoch - 4ms/step
# Epoch 29/300
# 13/13 - 0s - loss: 0.0013 - val_loss: 0.0172 - 48ms/epoch - 4ms/step
# Epoch 30/300
# 13/13 - 0s - loss: 0.0012 - val_loss: 0.0184 - 45ms/epoch - 3ms/step
# Epoch 31/300
# 13/13 - 0s - loss: 0.0013 - val_loss: 0.0170 - 45ms/epoch - 3ms/step
# Epoch 32/300
# 13/13 - 0s - loss: 0.0016 - val_loss: 0.0185 - 42ms/epoch - 3ms/step
# Epoch 33/300
# 13/13 - 0s - loss: 0.0014 - val_loss: 0.0181 - 45ms/epoch - 3ms/step
# Epoch 34/300
# 13/13 - 0s - loss: 0.0014 - val_loss: 0.0169 - 44ms/epoch - 3ms/step
# Epoch 35/300
# 13/13 - 0s - loss: 0.0020 - val_loss: 0.0181 - 77ms/epoch - 6ms/step
# Epoch 36/300
# 13/13 - 0s - loss: 0.0018 - val_loss: 0.0180 - 47ms/epoch - 4ms/step
# Epoch 37/300
# 13/13 - 0s - loss: 0.0019 - val_loss: 0.0196 - 48ms/epoch - 4ms/step
# Epoch 38/300
# 13/13 - 0s - loss: 0.0016 - val_loss: 0.0174 - 45ms/epoch - 3ms/step
# Epoch 39/300
# 13/13 - 0s - loss: 0.0012 - val_loss: 0.0179 - 45ms/epoch - 3ms/step
# Epoch 40/300
# 13/13 - 0s - loss: 0.0013 - val_loss: 0.0181 - 45ms/epoch - 3ms/step
# Epoch 41/300
# 13/13 - 0s - loss: 0.0013 - val_loss: 0.0179 - 43ms/epoch - 3ms/step
# Epoch 42/300
# 13/13 - 0s - loss: 0.0013 - val_loss: 0.0179 - 44ms/epoch - 3ms/step
# Epoch 43/300
# 13/13 - 0s - loss: 0.0012 - val_loss: 0.0186 - 45ms/epoch - 3ms/step
# Epoch 44/300
# 13/13 - 0s - loss: 0.0012 - val_loss: 0.0178 - 50ms/epoch - 4ms/step
# Epoch 45/300
# 13/13 - 0s - loss: 0.0012 - val_loss: 0.0183 - 47ms/epoch - 4ms/step
# Epoch 46/300
# 13/13 - 0s - loss: 0.0012 - val_loss: 0.0187 - 43ms/epoch - 3ms/step
# Epoch 47/300
# 13/13 - 0s - loss: 0.0015 - val_loss: 0.0180 - 44ms/epoch - 3ms/step
# Epoch 48/300
# 13/13 - 0s - loss: 0.0013 - val_loss: 0.0180 - 45ms/epoch - 3ms/step
# Epoch 49/300
# 13/13 - 0s - loss: 0.0011 - val_loss: 0.0179 - 46ms/epoch - 4ms/step
# Epoch 50/300
# 13/13 - 0s - loss: 0.0013 - val_loss: 0.0178 - 48ms/epoch - 4ms/step
# Epoch 51/300
# 13/13 - 0s - loss: 0.0013 - val_loss: 0.0178 - 47ms/epoch - 4ms/step
# Epoch 52/300
# 13/13 - 0s - loss: 0.0012 - val_loss: 0.0192 - 43ms/epoch - 3ms/step
# Epoch 53/300
# 13/13 - 0s - loss: 0.0012 - val_loss: 0.0176 - 43ms/epoch - 3ms/step
# Epoch 54/300
# 13/13 - 0s - loss: 0.0011 - val_loss: 0.0190 - 46ms/epoch - 4ms/step
# Epoch 55/300
# 13/13 - 0s - loss: 0.0013 - val_loss: 0.0187 - 49ms/epoch - 4ms/step
# Epoch 56/300
# 13/13 - 0s - loss: 0.0011 - val_loss: 0.0178 - 49ms/epoch - 4ms/step
# Epoch 57/300
# 13/13 - 0s - loss: 0.0012 - val_loss: 0.0187 - 45ms/epoch - 3ms/step
# Epoch 58/300
# 13/13 - 0s - loss: 0.0013 - val_loss: 0.0172 - 42ms/epoch - 3ms/step
# Epoch 59/300
# 13/13 - 0s - loss: 0.0013 - val_loss: 0.0192 - 42ms/epoch - 3ms/step
# Epoch 60/300
# 13/13 - 0s - loss: 0.0014 - val_loss: 0.0177 - 42ms/epoch - 3ms/step
# Epoch 61/300
# 13/13 - 0s - loss: 0.0014 - val_loss: 0.0181 - 42ms/epoch - 3ms/step
# Epoch 62/300
# 13/13 - 0s - loss: 0.0014 - val_loss: 0.0176 - 44ms/epoch - 3ms/step
# Epoch 63/300
# 13/13 - 0s - loss: 0.0018 - val_loss: 0.0188 - 41ms/epoch - 3ms/step
# Epoch 64/300
# 13/13 - 0s - loss: 0.0018 - val_loss: 0.0200 - 44ms/epoch - 3ms/step
# Epoch 65/300
# 13/13 - 0s - loss: 0.0015 - val_loss: 0.0174 - 41ms/epoch - 3ms/step
# Epoch 66/300
# 13/13 - 0s - loss: 0.0013 - val_loss: 0.0190 - 44ms/epoch - 3ms/step
# Epoch 67/300
# 13/13 - 0s - loss: 0.0012 - val_loss: 0.0185 - 44ms/epoch - 3ms/step
# Epoch 68/300
# 13/13 - 0s - loss: 0.0011 - val_loss: 0.0183 - 43ms/epoch - 3ms/step
# Epoch 69/300
# 13/13 - 0s - loss: 0.0011 - val_loss: 0.0182 - 42ms/epoch - 3ms/step
# Epoch 70/300
# 13/13 - 0s - loss: 0.0011 - val_loss: 0.0184 - 43ms/epoch - 3ms/step
# Epoch 71/300
# 13/13 - 0s - loss: 0.0011 - val_loss: 0.0182 - 41ms/epoch - 3ms/step
# Epoch 72/300
# 13/13 - 0s - loss: 0.0011 - val_loss: 0.0176 - 43ms/epoch - 3ms/step
# Epoch 73/300
# 13/13 - 0s - loss: 0.0011 - val_loss: 0.0189 - 44ms/epoch - 3ms/step
# Epoch 74/300
# 13/13 - 0s - loss: 0.0011 - val_loss: 0.0195 - 42ms/epoch - 3ms/step
# Epoch 75/300
# 13/13 - 0s - loss: 0.0012 - val_loss: 0.0182 - 44ms/epoch - 3ms/step
# Epoch 76/300
# 13/13 - 0s - loss: 0.0011 - val_loss: 0.0182 - 45ms/epoch - 3ms/step
# Epoch 77/300
# 13/13 - 0s - loss: 0.0011 - val_loss: 0.0179 - 46ms/epoch - 4ms/step
# Epoch 78/300
# 13/13 - 0s - loss: 0.0011 - val_loss: 0.0197 - 46ms/epoch - 4ms/step
# Epoch 79/300
# 13/13 - 0s - loss: 0.0013 - val_loss: 0.0199 - 48ms/epoch - 4ms/step
# Epoch 80/300
# 13/13 - 0s - loss: 0.0012 - val_loss: 0.0187 - 45ms/epoch - 3ms/step
# Epoch 81/300
# 13/13 - 0s - loss: 0.0012 - val_loss: 0.0176 - 45ms/epoch - 3ms/step
# Epoch 82/300
# 13/13 - 0s - loss: 0.0010 - val_loss: 0.0176 - 45ms/epoch - 3ms/step
# Epoch 83/300
# 13/13 - 0s - loss: 0.0011 - val_loss: 0.0199 - 46ms/epoch - 4ms/step
# Epoch 84/300
# 13/13 - 0s - loss: 0.0011 - val_loss: 0.0191 - 47ms/epoch - 4ms/step
# Epoch 85/300
# 13/13 - 0s - loss: 0.0013 - val_loss: 0.0194 - 43ms/epoch - 3ms/step
# Epoch 86/300
# 13/13 - 0s - loss: 0.0012 - val_loss: 0.0179 - 42ms/epoch - 3ms/step
# Epoch 87/300
# 13/13 - 0s - loss: 0.0012 - val_loss: 0.0205 - 44ms/epoch - 3ms/step
# Epoch 88/300
# 13/13 - 0s - loss: 0.0011 - val_loss: 0.0176 - 44ms/epoch - 3ms/step
# Epoch 89/300
# 13/13 - 0s - loss: 0.0013 - val_loss: 0.0172 - 49ms/epoch - 4ms/step
# Epoch 90/300
# 13/13 - 0s - loss: 0.0012 - val_loss: 0.0191 - 42ms/epoch - 3ms/step
# Epoch 91/300
# 13/13 - 0s - loss: 0.0010 - val_loss: 0.0179 - 44ms/epoch - 3ms/step
# Epoch 92/300
# 13/13 - 0s - loss: 9.9144e-04 - val_loss: 0.0192 - 45ms/epoch - 3ms/step
# Epoch 93/300
# 13/13 - 0s - loss: 0.0011 - val_loss: 0.0190 - 44ms/epoch - 3ms/step
# Epoch 94/300
# 13/13 - 0s - loss: 9.7135e-04 - val_loss: 0.0189 - 47ms/epoch - 4ms/step
# Epoch 95/300
# 13/13 - 0s - loss: 9.4038e-04 - val_loss: 0.0177 - 43ms/epoch - 3ms/step
# Epoch 96/300
# 13/13 - 0s - loss: 9.8704e-04 - val_loss: 0.0193 - 41ms/epoch - 3ms/step
# Epoch 97/300
# 13/13 - 0s - loss: 0.0011 - val_loss: 0.0178 - 40ms/epoch - 3ms/step
# Epoch 98/300
# 13/13 - 0s - loss: 0.0011 - val_loss: 0.0183 - 43ms/epoch - 3ms/step
# Epoch 99/300
# 13/13 - 0s - loss: 0.0011 - val_loss: 0.0189 - 45ms/epoch - 3ms/step
# Epoch 100/300
# 13/13 - 0s - loss: 9.6889e-04 - val_loss: 0.0179 - 44ms/epoch - 3ms/step
# Epoch 101/300
# 13/13 - 0s - loss: 0.0011 - val_loss: 0.0185 - 43ms/epoch - 3ms/step
# Epoch 102/300
# 13/13 - 0s - loss: 0.0011 - val_loss: 0.0180 - 44ms/epoch - 3ms/step
# Epoch 103/300
# 13/13 - 0s - loss: 0.0011 - val_loss: 0.0181 - 50ms/epoch - 4ms/step
# Epoch 104/300
# 13/13 - 0s - loss: 9.4088e-04 - val_loss: 0.0182 - 46ms/epoch - 4ms/step
# Epoch 105/300
# 13/13 - 0s - loss: 0.0012 - val_loss: 0.0173 - 48ms/epoch - 4ms/step
# Epoch 106/300
# 13/13 - 0s - loss: 9.7224e-04 - val_loss: 0.0183 - 47ms/epoch - 4ms/step
# Epoch 107/300
# 13/13 - 0s - loss: 8.5424e-04 - val_loss: 0.0197 - 46ms/epoch - 4ms/step
# Epoch 108/300
# 13/13 - 0s - loss: 9.3281e-04 - val_loss: 0.0198 - 42ms/epoch - 3ms/step
# Epoch 109/300
# 13/13 - 0s - loss: 0.0012 - val_loss: 0.0193 - 42ms/epoch - 3ms/step
# Epoch 110/300
# 13/13 - 0s - loss: 0.0013 - val_loss: 0.0184 - 47ms/epoch - 4ms/step
# Epoch 111/300
# 13/13 - 0s - loss: 0.0010 - val_loss: 0.0189 - 45ms/epoch - 3ms/step
# Epoch 112/300
# 13/13 - 0s - loss: 0.0011 - val_loss: 0.0187 - 44ms/epoch - 3ms/step
# Epoch 113/300
# 13/13 - 0s - loss: 9.2510e-04 - val_loss: 0.0193 - 43ms/epoch - 3ms/step
# Epoch 114/300
# 13/13 - 0s - loss: 9.4057e-04 - val_loss: 0.0189 - 44ms/epoch - 3ms/step
# Epoch 115/300
# 13/13 - 0s - loss: 9.0848e-04 - val_loss: 0.0182 - 45ms/epoch - 3ms/step
# Epoch 116/300
# 13/13 - 0s - loss: 9.8794e-04 - val_loss: 0.0195 - 44ms/epoch - 3ms/step
# Epoch 117/300
# 13/13 - 0s - loss: 8.5889e-04 - val_loss: 0.0176 - 43ms/epoch - 3ms/step
# Epoch 118/300
# 13/13 - 0s - loss: 9.4431e-04 - val_loss: 0.0190 - 44ms/epoch - 3ms/step
# Epoch 119/300
# 13/13 - 0s - loss: 9.1271e-04 - val_loss: 0.0185 - 43ms/epoch - 3ms/step
# Epoch 120/300
# 13/13 - 0s - loss: 0.0011 - val_loss: 0.0189 - 42ms/epoch - 3ms/step
# Epoch 121/300
# 13/13 - 0s - loss: 9.8353e-04 - val_loss: 0.0182 - 43ms/epoch - 3ms/step
# Epoch 122/300
# 13/13 - 0s - loss: 8.6657e-04 - val_loss: 0.0188 - 45ms/epoch - 3ms/step
# Epoch 123/300
# 13/13 - 0s - loss: 8.2874e-04 - val_loss: 0.0195 - 43ms/epoch - 3ms/step
# Epoch 124/300
# 13/13 - 0s - loss: 8.5469e-04 - val_loss: 0.0190 - 53ms/epoch - 4ms/step
# Epoch 125/300
# 13/13 - 0s - loss: 9.0735e-04 - val_loss: 0.0183 - 44ms/epoch - 3ms/step
# Epoch 126/300
# 13/13 - 0s - loss: 8.2183e-04 - val_loss: 0.0185 - 42ms/epoch - 3ms/step
# Epoch 127/300
# 13/13 - 0s - loss: 7.7038e-04 - val_loss: 0.0187 - 42ms/epoch - 3ms/step
# Epoch 128/300
# 13/13 - 0s - loss: 8.8484e-04 - val_loss: 0.0190 - 43ms/epoch - 3ms/step
# Epoch 129/300
# 13/13 - 0s - loss: 9.7284e-04 - val_loss: 0.0194 - 43ms/epoch - 3ms/step
# Epoch 130/300
# 13/13 - 0s - loss: 8.2213e-04 - val_loss: 0.0183 - 43ms/epoch - 3ms/step
# Epoch 131/300
# 13/13 - 0s - loss: 9.1513e-04 - val_loss: 0.0196 - 45ms/epoch - 3ms/step
# Epoch 132/300
# 13/13 - 0s - loss: 8.7746e-04 - val_loss: 0.0180 - 44ms/epoch - 3ms/step
# Epoch 133/300
# 13/13 - 0s - loss: 8.2686e-04 - val_loss: 0.0187 - 44ms/epoch - 3ms/step
# Epoch 134/300
# 13/13 - 0s - loss: 7.9306e-04 - val_loss: 0.0197 - 43ms/epoch - 3ms/step
# Epoch 135/300
# 13/13 - 0s - loss: 7.6092e-04 - val_loss: 0.0192 - 42ms/epoch - 3ms/step
# Epoch 136/300
# 13/13 - 0s - loss: 7.9774e-04 - val_loss: 0.0188 - 43ms/epoch - 3ms/step
# Epoch 137/300
# 13/13 - 0s - loss: 8.8490e-04 - val_loss: 0.0185 - 42ms/epoch - 3ms/step
# Epoch 138/300
# 13/13 - 0s - loss: 8.9851e-04 - val_loss: 0.0196 - 43ms/epoch - 3ms/step
# Epoch 139/300
# 13/13 - 0s - loss: 7.7643e-04 - val_loss: 0.0187 - 45ms/epoch - 3ms/step
# Epoch 140/300
# 13/13 - 0s - loss: 7.8102e-04 - val_loss: 0.0186 - 44ms/epoch - 3ms/step
# Epoch 141/300
# 13/13 - 0s - loss: 8.0185e-04 - val_loss: 0.0186 - 45ms/epoch - 3ms/step
# Epoch 142/300
# 13/13 - 0s - loss: 7.2432e-04 - val_loss: 0.0192 - 46ms/epoch - 4ms/step
# Epoch 143/300
# 13/13 - 0s - loss: 7.6180e-04 - val_loss: 0.0193 - 41ms/epoch - 3ms/step
# Epoch 144/300
# 13/13 - 0s - loss: 7.6092e-04 - val_loss: 0.0191 - 40ms/epoch - 3ms/step
# Epoch 145/300
# 13/13 - 0s - loss: 8.9760e-04 - val_loss: 0.0191 - 44ms/epoch - 3ms/step
# Epoch 146/300
# 13/13 - 0s - loss: 0.0011 - val_loss: 0.0197 - 45ms/epoch - 3ms/step
# Epoch 147/300
# 13/13 - 0s - loss: 9.3932e-04 - val_loss: 0.0194 - 44ms/epoch - 3ms/step
# Epoch 148/300
# 13/13 - 0s - loss: 8.9494e-04 - val_loss: 0.0193 - 43ms/epoch - 3ms/step
# Epoch 149/300
# 13/13 - 0s - loss: 9.4969e-04 - val_loss: 0.0194 - 42ms/epoch - 3ms/step
# Epoch 150/300
# 13/13 - 0s - loss: 9.9093e-04 - val_loss: 0.0183 - 42ms/epoch - 3ms/step
# Epoch 151/300
# 13/13 - 0s - loss: 9.5542e-04 - val_loss: 0.0194 - 75ms/epoch - 6ms/step
# Epoch 152/300
# 13/13 - 0s - loss: 9.8500e-04 - val_loss: 0.0179 - 42ms/epoch - 3ms/step
# Epoch 153/300
# 13/13 - 0s - loss: 0.0011 - val_loss: 0.0204 - 43ms/epoch - 3ms/step
# Epoch 154/300
# 13/13 - 0s - loss: 0.0013 - val_loss: 0.0182 - 48ms/epoch - 4ms/step
# Epoch 155/300
# 13/13 - 0s - loss: 0.0012 - val_loss: 0.0197 - 43ms/epoch - 3ms/step
# Epoch 156/300
# 13/13 - 0s - loss: 0.0012 - val_loss: 0.0199 - 42ms/epoch - 3ms/step
# Epoch 157/300
# 13/13 - 0s - loss: 0.0012 - val_loss: 0.0187 - 39ms/epoch - 3ms/step
# Epoch 158/300
# 13/13 - 0s - loss: 9.0738e-04 - val_loss: 0.0186 - 43ms/epoch - 3ms/step
# Epoch 159/300
# 13/13 - 0s - loss: 9.6698e-04 - val_loss: 0.0204 - 44ms/epoch - 3ms/step
# Epoch 160/300
# 13/13 - 0s - loss: 0.0013 - val_loss: 0.0185 - 43ms/epoch - 3ms/step
# Epoch 161/300
# 13/13 - 0s - loss: 8.5502e-04 - val_loss: 0.0198 - 40ms/epoch - 3ms/step
# Epoch 162/300
# 13/13 - 0s - loss: 0.0010 - val_loss: 0.0198 - 44ms/epoch - 3ms/step
# Epoch 163/300
# 13/13 - 0s - loss: 8.1449e-04 - val_loss: 0.0193 - 45ms/epoch - 3ms/step
# Epoch 164/300
# 13/13 - 0s - loss: 9.2096e-04 - val_loss: 0.0194 - 45ms/epoch - 3ms/step
# Epoch 165/300
# 13/13 - 0s - loss: 9.0425e-04 - val_loss: 0.0182 - 43ms/epoch - 3ms/step
# Epoch 166/300
# 13/13 - 0s - loss: 6.8262e-04 - val_loss: 0.0193 - 42ms/epoch - 3ms/step
# Epoch 167/300
# 13/13 - 0s - loss: 7.3325e-04 - val_loss: 0.0182 - 41ms/epoch - 3ms/step
# Epoch 168/300
# 13/13 - 0s - loss: 9.9929e-04 - val_loss: 0.0197 - 41ms/epoch - 3ms/step
# Epoch 169/300
# 13/13 - 0s - loss: 0.0011 - val_loss: 0.0205 - 43ms/epoch - 3ms/step
# Epoch 170/300
# 13/13 - 0s - loss: 0.0013 - val_loss: 0.0199 - 42ms/epoch - 3ms/step
# Epoch 171/300
# 13/13 - 0s - loss: 0.0013 - val_loss: 0.0211 - 54ms/epoch - 4ms/step
# Epoch 172/300
# 13/13 - 0s - loss: 0.0011 - val_loss: 0.0183 - 52ms/epoch - 4ms/step
# Epoch 173/300
# 13/13 - 0s - loss: 8.9784e-04 - val_loss: 0.0188 - 54ms/epoch - 4ms/step
# Epoch 174/300
# 13/13 - 0s - loss: 8.6851e-04 - val_loss: 0.0199 - 52ms/epoch - 4ms/step
# Epoch 175/300
# 13/13 - 0s - loss: 9.5897e-04 - val_loss: 0.0187 - 52ms/epoch - 4ms/step
# Epoch 176/300
# 13/13 - 0s - loss: 8.7560e-04 - val_loss: 0.0192 - 54ms/epoch - 4ms/step
# Epoch 177/300
# 13/13 - 0s - loss: 8.1238e-04 - val_loss: 0.0185 - 52ms/epoch - 4ms/step
# Epoch 178/300
# 13/13 - 0s - loss: 0.0013 - val_loss: 0.0183 - 51ms/epoch - 4ms/step
# Epoch 179/300
# 13/13 - 0s - loss: 0.0014 - val_loss: 0.0174 - 47ms/epoch - 4ms/step
# Epoch 180/300
# 13/13 - 0s - loss: 0.0011 - val_loss: 0.0209 - 43ms/epoch - 3ms/step
# Epoch 181/300
# 13/13 - 0s - loss: 0.0011 - val_loss: 0.0190 - 42ms/epoch - 3ms/step
# Epoch 182/300
# 13/13 - 0s - loss: 8.9020e-04 - val_loss: 0.0190 - 45ms/epoch - 3ms/step
# Epoch 183/300
# 13/13 - 0s - loss: 0.0012 - val_loss: 0.0186 - 55ms/epoch - 4ms/step
# Epoch 184/300
# 13/13 - 0s - loss: 0.0011 - val_loss: 0.0203 - 56ms/epoch - 4ms/step
# Epoch 185/300
# 13/13 - 0s - loss: 0.0012 - val_loss: 0.0182 - 51ms/epoch - 4ms/step
# Epoch 186/300
# 13/13 - 0s - loss: 0.0012 - val_loss: 0.0185 - 53ms/epoch - 4ms/step
# Epoch 187/300
# 13/13 - 0s - loss: 9.6274e-04 - val_loss: 0.0191 - 49ms/epoch - 4ms/step
# Epoch 188/300
# 13/13 - 0s - loss: 7.6956e-04 - val_loss: 0.0188 - 52ms/epoch - 4ms/step
# Epoch 189/300
# 13/13 - 0s - loss: 8.2044e-04 - val_loss: 0.0197 - 52ms/epoch - 4ms/step
# Epoch 190/300
# 13/13 - 0s - loss: 8.1044e-04 - val_loss: 0.0189 - 50ms/epoch - 4ms/step
# Epoch 191/300
# 13/13 - 0s - loss: 8.0563e-04 - val_loss: 0.0192 - 44ms/epoch - 3ms/step
# Epoch 192/300
# 13/13 - 0s - loss: 7.4045e-04 - val_loss: 0.0197 - 57ms/epoch - 4ms/step
# Epoch 193/300
# 13/13 - 0s - loss: 7.1580e-04 - val_loss: 0.0191 - 54ms/epoch - 4ms/step
# Epoch 194/300
# 13/13 - 0s - loss: 6.5584e-04 - val_loss: 0.0192 - 53ms/epoch - 4ms/step
# Epoch 195/300
# 13/13 - 0s - loss: 6.2386e-04 - val_loss: 0.0191 - 54ms/epoch - 4ms/step
# Epoch 196/300
# 13/13 - 0s - loss: 6.3867e-04 - val_loss: 0.0189 - 53ms/epoch - 4ms/step
# Epoch 197/300
# 13/13 - 0s - loss: 8.6366e-04 - val_loss: 0.0174 - 50ms/epoch - 4ms/step
# Epoch 198/300
# 13/13 - 0s - loss: 0.0012 - val_loss: 0.0189 - 53ms/epoch - 4ms/step
# Epoch 199/300
# 13/13 - 0s - loss: 0.0013 - val_loss: 0.0184 - 54ms/epoch - 4ms/step
# Epoch 200/300
# 13/13 - 0s - loss: 9.7756e-04 - val_loss: 0.0202 - 47ms/epoch - 4ms/step
# Epoch 201/300
# 13/13 - 0s - loss: 8.7620e-04 - val_loss: 0.0193 - 42ms/epoch - 3ms/step
# Epoch 202/300
# 13/13 - 0s - loss: 7.7954e-04 - val_loss: 0.0187 - 42ms/epoch - 3ms/step
# Epoch 203/300
# 13/13 - 0s - loss: 8.0470e-04 - val_loss: 0.0209 - 43ms/epoch - 3ms/step
# Epoch 204/300
# 13/13 - 0s - loss: 8.3074e-04 - val_loss: 0.0186 - 40ms/epoch - 3ms/step
# Epoch 205/300
# 13/13 - 0s - loss: 7.8311e-04 - val_loss: 0.0186 - 45ms/epoch - 3ms/step
# Epoch 206/300
# 13/13 - 0s - loss: 7.2855e-04 - val_loss: 0.0185 - 47ms/epoch - 4ms/step
# Epoch 207/300
# 13/13 - 0s - loss: 9.6721e-04 - val_loss: 0.0202 - 42ms/epoch - 3ms/step
# Epoch 208/300
# 13/13 - 0s - loss: 0.0011 - val_loss: 0.0180 - 41ms/epoch - 3ms/step
# Epoch 209/300
# 13/13 - 0s - loss: 0.0012 - val_loss: 0.0191 - 44ms/epoch - 3ms/step
# Epoch 210/300
# 13/13 - 0s - loss: 8.4949e-04 - val_loss: 0.0193 - 44ms/epoch - 3ms/step
# Epoch 211/300
# 13/13 - 0s - loss: 9.6717e-04 - val_loss: 0.0179 - 77ms/epoch - 6ms/step
# Epoch 212/300
# 13/13 - 0s - loss: 0.0014 - val_loss: 0.0205 - 44ms/epoch - 3ms/step
# Epoch 213/300
# 13/13 - 0s - loss: 0.0013 - val_loss: 0.0191 - 45ms/epoch - 3ms/step
# Epoch 214/300
# 13/13 - 0s - loss: 0.0016 - val_loss: 0.0183 - 45ms/epoch - 3ms/step
# Epoch 215/300
# 13/13 - 0s - loss: 0.0017 - val_loss: 0.0172 - 44ms/epoch - 3ms/step
# Epoch 216/300
# 13/13 - 0s - loss: 0.0015 - val_loss: 0.0190 - 43ms/epoch - 3ms/step
# Epoch 217/300
# 13/13 - 0s - loss: 9.5731e-04 - val_loss: 0.0184 - 41ms/epoch - 3ms/step
# Epoch 218/300
# 13/13 - 0s - loss: 8.9125e-04 - val_loss: 0.0196 - 40ms/epoch - 3ms/step
# Epoch 219/300
# 13/13 - 0s - loss: 6.9657e-04 - val_loss: 0.0182 - 44ms/epoch - 3ms/step
# Epoch 220/300
# 13/13 - 0s - loss: 6.5032e-04 - val_loss: 0.0180 - 44ms/epoch - 3ms/step
# Epoch 221/300
# 13/13 - 0s - loss: 6.7697e-04 - val_loss: 0.0187 - 47ms/epoch - 4ms/step
# Epoch 222/300
# 13/13 - 0s - loss: 9.1738e-04 - val_loss: 0.0179 - 47ms/epoch - 4ms/step
# Epoch 223/300
# 13/13 - 0s - loss: 9.6826e-04 - val_loss: 0.0203 - 42ms/epoch - 3ms/step
# Epoch 224/300
# 13/13 - 0s - loss: 8.4846e-04 - val_loss: 0.0201 - 45ms/epoch - 3ms/step
# Epoch 225/300
# 13/13 - 0s - loss: 9.1000e-04 - val_loss: 0.0195 - 51ms/epoch - 4ms/step
# Epoch 226/300
# 13/13 - 0s - loss: 7.5806e-04 - val_loss: 0.0189 - 55ms/epoch - 4ms/step
# Epoch 227/300
# 13/13 - 0s - loss: 7.3731e-04 - val_loss: 0.0192 - 53ms/epoch - 4ms/step
# Epoch 228/300
# 13/13 - 0s - loss: 7.1627e-04 - val_loss: 0.0192 - 54ms/epoch - 4ms/step
# Epoch 229/300
# 13/13 - 0s - loss: 7.5576e-04 - val_loss: 0.0188 - 55ms/epoch - 4ms/step
# Epoch 230/300
# 13/13 - 0s - loss: 6.5405e-04 - val_loss: 0.0185 - 52ms/epoch - 4ms/step
# Epoch 231/300
# 13/13 - 0s - loss: 6.1037e-04 - val_loss: 0.0193 - 55ms/epoch - 4ms/step
# Epoch 232/300
# 13/13 - 0s - loss: 5.8464e-04 - val_loss: 0.0192 - 56ms/epoch - 4ms/step
# Epoch 233/300
# 13/13 - 0s - loss: 7.1115e-04 - val_loss: 0.0200 - 49ms/epoch - 4ms/step
# Epoch 234/300
# 13/13 - 0s - loss: 9.5177e-04 - val_loss: 0.0172 - 45ms/epoch - 3ms/step
# Epoch 235/300
# 13/13 - 0s - loss: 0.0010 - val_loss: 0.0186 - 43ms/epoch - 3ms/step
# Epoch 236/300
# 13/13 - 0s - loss: 0.0012 - val_loss: 0.0184 - 45ms/epoch - 3ms/step
# Epoch 237/300
# 13/13 - 0s - loss: 6.0527e-04 - val_loss: 0.0195 - 42ms/epoch - 3ms/step
# Epoch 238/300
# 13/13 - 0s - loss: 5.5708e-04 - val_loss: 0.0196 - 42ms/epoch - 3ms/step
# Epoch 239/300
# 13/13 - 0s - loss: 5.3721e-04 - val_loss: 0.0198 - 42ms/epoch - 3ms/step
# Epoch 240/300
# 13/13 - 0s - loss: 5.5695e-04 - val_loss: 0.0196 - 44ms/epoch - 3ms/step
# Epoch 241/300
# 13/13 - 0s - loss: 6.6182e-04 - val_loss: 0.0193 - 42ms/epoch - 3ms/step
# Epoch 242/300
# 13/13 - 0s - loss: 6.6529e-04 - val_loss: 0.0188 - 41ms/epoch - 3ms/step
# Epoch 243/300
# 13/13 - 0s - loss: 6.9233e-04 - val_loss: 0.0187 - 46ms/epoch - 4ms/step
# Epoch 244/300
# 13/13 - 0s - loss: 7.5639e-04 - val_loss: 0.0207 - 43ms/epoch - 3ms/step
# Epoch 245/300
# 13/13 - 0s - loss: 5.4505e-04 - val_loss: 0.0194 - 41ms/epoch - 3ms/step
# Epoch 246/300
# 13/13 - 0s - loss: 6.5517e-04 - val_loss: 0.0208 - 44ms/epoch - 3ms/step
# Epoch 247/300
# 13/13 - 0s - loss: 7.3938e-04 - val_loss: 0.0193 - 42ms/epoch - 3ms/step
# Epoch 248/300
# 13/13 - 0s - loss: 6.1214e-04 - val_loss: 0.0193 - 41ms/epoch - 3ms/step
# Epoch 249/300
# 13/13 - 0s - loss: 7.5137e-04 - val_loss: 0.0191 - 43ms/epoch - 3ms/step
# Epoch 250/300
# 13/13 - 0s - loss: 6.2082e-04 - val_loss: 0.0191 - 42ms/epoch - 3ms/step
# Epoch 251/300
# 13/13 - 0s - loss: 7.0716e-04 - val_loss: 0.0207 - 42ms/epoch - 3ms/step
# Epoch 252/300
# 13/13 - 0s - loss: 7.0450e-04 - val_loss: 0.0190 - 41ms/epoch - 3ms/step
# Epoch 253/300
# 13/13 - 0s - loss: 6.7405e-04 - val_loss: 0.0201 - 44ms/epoch - 3ms/step
# Epoch 254/300
# 13/13 - 0s - loss: 6.1448e-04 - val_loss: 0.0190 - 45ms/epoch - 3ms/step
# Epoch 255/300
# 13/13 - 0s - loss: 6.1104e-04 - val_loss: 0.0191 - 45ms/epoch - 3ms/step
# Epoch 256/300
# 13/13 - 0s - loss: 5.8065e-04 - val_loss: 0.0194 - 44ms/epoch - 3ms/step
# Epoch 257/300
# 13/13 - 0s - loss: 4.9892e-04 - val_loss: 0.0189 - 44ms/epoch - 3ms/step
# Epoch 258/300
# 13/13 - 0s - loss: 5.4032e-04 - val_loss: 0.0195 - 51ms/epoch - 4ms/step
# Epoch 259/300
# 13/13 - 0s - loss: 5.2192e-04 - val_loss: 0.0200 - 56ms/epoch - 4ms/step
# Epoch 260/300
# 13/13 - 0s - loss: 6.2380e-04 - val_loss: 0.0202 - 52ms/epoch - 4ms/step
# Epoch 261/300
# 13/13 - 0s - loss: 5.7938e-04 - val_loss: 0.0192 - 51ms/epoch - 4ms/step
# Epoch 262/300
# 13/13 - 0s - loss: 5.8343e-04 - val_loss: 0.0195 - 50ms/epoch - 4ms/step
# Epoch 263/300
# 13/13 - 0s - loss: 7.3700e-04 - val_loss: 0.0197 - 53ms/epoch - 4ms/step
# Epoch 264/300
# 13/13 - 0s - loss: 0.0011 - val_loss: 0.0200 - 50ms/epoch - 4ms/step
# Epoch 265/300
# 13/13 - 0s - loss: 8.1610e-04 - val_loss: 0.0194 - 52ms/epoch - 4ms/step
# Epoch 266/300
# 13/13 - 0s - loss: 6.9600e-04 - val_loss: 0.0197 - 52ms/epoch - 4ms/step
# Epoch 267/300
# 13/13 - 0s - loss: 6.6304e-04 - val_loss: 0.0194 - 75ms/epoch - 6ms/step
# Epoch 268/300
# 13/13 - 0s - loss: 5.6896e-04 - val_loss: 0.0196 - 43ms/epoch - 3ms/step
# Epoch 269/300
# 13/13 - 0s - loss: 5.1085e-04 - val_loss: 0.0188 - 45ms/epoch - 3ms/step
# Epoch 270/300
# 13/13 - 0s - loss: 5.3100e-04 - val_loss: 0.0200 - 43ms/epoch - 3ms/step
# Epoch 271/300
# 13/13 - 0s - loss: 5.5150e-04 - val_loss: 0.0193 - 42ms/epoch - 3ms/step
# Epoch 272/300
# 13/13 - 0s - loss: 4.2598e-04 - val_loss: 0.0199 - 43ms/epoch - 3ms/step
# Epoch 273/300
# 13/13 - 0s - loss: 4.1106e-04 - val_loss: 0.0185 - 43ms/epoch - 3ms/step
# Epoch 274/300
# 13/13 - 0s - loss: 4.9442e-04 - val_loss: 0.0195 - 42ms/epoch - 3ms/step
# Epoch 275/300
# 13/13 - 0s - loss: 5.5251e-04 - val_loss: 0.0196 - 44ms/epoch - 3ms/step
# Epoch 276/300
# 13/13 - 0s - loss: 5.9800e-04 - val_loss: 0.0206 - 44ms/epoch - 3ms/step
# Epoch 277/300
# 13/13 - 0s - loss: 0.0010 - val_loss: 0.0203 - 40ms/epoch - 3ms/step
# Epoch 278/300
# 13/13 - 0s - loss: 9.8303e-04 - val_loss: 0.0187 - 48ms/epoch - 4ms/step
# Epoch 279/300
# 13/13 - 0s - loss: 0.0012 - val_loss: 0.0182 - 47ms/epoch - 4ms/step
# Epoch 280/300
# 13/13 - 0s - loss: 0.0011 - val_loss: 0.0203 - 42ms/epoch - 3ms/step
# Epoch 281/300
# 13/13 - 0s - loss: 8.9302e-04 - val_loss: 0.0190 - 41ms/epoch - 3ms/step
# Epoch 282/300
# 13/13 - 0s - loss: 6.9524e-04 - val_loss: 0.0202 - 42ms/epoch - 3ms/step
# Epoch 283/300
# 13/13 - 0s - loss: 6.7765e-04 - val_loss: 0.0186 - 41ms/epoch - 3ms/step
# Epoch 284/300
# 13/13 - 0s - loss: 6.1595e-04 - val_loss: 0.0193 - 45ms/epoch - 3ms/step
# Epoch 285/300
# 13/13 - 0s - loss: 6.1899e-04 - val_loss: 0.0197 - 42ms/epoch - 3ms/step
# Epoch 286/300
# 13/13 - 0s - loss: 6.3494e-04 - val_loss: 0.0198 - 43ms/epoch - 3ms/step
# Epoch 287/300
# 13/13 - 0s - loss: 7.4953e-04 - val_loss: 0.0196 - 45ms/epoch - 3ms/step
# Epoch 288/300
# 13/13 - 0s - loss: 6.4401e-04 - val_loss: 0.0200 - 43ms/epoch - 3ms/step
# Epoch 289/300
# 13/13 - 0s - loss: 6.4694e-04 - val_loss: 0.0196 - 42ms/epoch - 3ms/step
# Epoch 290/300
# 13/13 - 0s - loss: 5.7294e-04 - val_loss: 0.0194 - 42ms/epoch - 3ms/step
# Epoch 291/300
# 13/13 - 0s - loss: 5.1769e-04 - val_loss: 0.0189 - 44ms/epoch - 3ms/step
# Epoch 292/300
# 13/13 - 0s - loss: 5.1719e-04 - val_loss: 0.0190 - 42ms/epoch - 3ms/step
# Epoch 293/300
# 13/13 - 0s - loss: 5.4166e-04 - val_loss: 0.0189 - 43ms/epoch - 3ms/step
# Epoch 294/300
# 13/13 - 0s - loss: 4.4690e-04 - val_loss: 0.0196 - 42ms/epoch - 3ms/step
# Epoch 295/300
# 13/13 - 0s - loss: 4.6076e-04 - val_loss: 0.0196 - 41ms/epoch - 3ms/step
# Epoch 296/300
# 13/13 - 0s - loss: 4.4493e-04 - val_loss: 0.0201 - 42ms/epoch - 3ms/step
# Epoch 297/300
# 13/13 - 0s - loss: 5.5534e-04 - val_loss: 0.0193 - 42ms/epoch - 3ms/step
# Epoch 298/300
# 13/13 - 0s - loss: 4.6372e-04 - val_loss: 0.0197 - 43ms/epoch - 3ms/step
# Epoch 299/300
# 13/13 - 0s - loss: 4.3939e-04 - val_loss: 0.0198 - 43ms/epoch - 3ms/step
# Epoch 300/300
# 13/13 - 0s - loss: 5.1987e-04 - val_loss: 0.0191 - 42ms/epoch - 3ms/step

# %%
# Predictions
predictions_scaled = model.predict(X_test)

# %%
# Inverse transform predictions
predictions = scaler_y.inverse_transform(predictions_scaled)

# Compare predictions with actual values (optional)
y_test_actual = scaler_y.inverse_transform(y_test)
comparison = pd.DataFrame({'Actual': y_test_actual.flatten(), 'Predicted': predictions.flatten()})
print(comparison.head())
# Out:
#    Actual  Predicted
# 0     4.0   4.746358
# 1     6.0   7.667839
# 2     7.0   5.306402
# 3     3.0   2.278131
# 4     3.0   3.953605

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

mse = mean_squared_error(y_test_actual, predictions)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test_actual, predictions)

print(f"Mean Squared Error: {mse}")
print(f"Root Mean Squared Error: {rmse}")
print(f"Mean Absolute Error: {mae}")
# Out:
# Mean Squared Error: 12.202341780649487
# Root Mean Squared Error: 3.493185048154404
# Mean Absolute Error: 2.543120525253952

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(y_test_actual, label='Actual')
plt.plot(predictions, label='Predicted', alpha=0.7)
plt.title('Actual vs Predicted Total Disasters')
plt.xlabel('Test Sample')
plt.ylabel('Total Disasters')
plt.legend()
plt.show()

# %%
def predict_disaster_for_country_year(data, model, scaler_X, scaler_y, feature_columns, country, input_year):
    # Convert input_year from string to int
    input_year = int(input_year)
    
    # Filter data for the selected country and up to the selected year
    country_data = data[(data['Country'] == country) & (data['Year'] >= input_year - 2) & (data['Year'] <= input_year)]
    
    if len(country_data) < 3:
        print(f"Not enough data for {country} leading up to {input_year}.")
        return
    
    # Convert to DataFrame to maintain feature names
    features_df = country_data[feature_columns]
    features_scaled = scaler_X.transform(features_df)  # Scale features
    features_reshaped = features_scaled.reshape(1, 3, len(feature_columns))  # Reshape for the model
    
    # Make prediction
    predicted_scaled = model.predict(features_reshaped)
    predicted = scaler_y.inverse_transform(predicted_scaled)[0][0]  # Inverse transform prediction
    
    # Get actual value for the year
    actual_value = data[(data['Country'] == country) & (data['Year'] == input_year)][target_column].values[0] if len(data[(data['Country'] == country) & (data['Year'] == input_year)][target_column]) > 0 else None
    
    if actual_value is not None:
        # Calculate accuracy percentage
        accuracy = max(0, 1 - abs(predicted - actual_value) / actual_value) * 100
        
        print(f"Country: {country}, Year: {input_year}")
        print(f"Actual 'Total Disasters': {actual_value}")
        print(f"Predicted 'Total Disasters': {predicted:.2f}")
        print(f"Accuracy: {accuracy:.2f}%")
    else:
        print(f"No actual data available for {country} in {input_year}.")
        print(f"Predicted 'Total Disasters': {predicted:.2f}")

# %%
# Example usage
user_country = input("Enter country name: ")
user_year = input("Enter a year between 2017 and 2020: ")

predict_disaster_for_country_year(data, model, scaler_X, scaler_y, feature_columns, user_country, user_year)
# Out:
# Enter country name:  India
# Enter a year between 2017 and 2020:  2019
# Country: India, Year: 2019
# Actual 'Total Disasters': 12
# Predicted 'Total Disasters': 14.40
# Accuracy: 80.01%

# %%
# Example usage
user_country = input("Enter country name: ")
user_year = input("Enter a year between 2017 and 2020: ")

predict_disaster_for_country_year(data, model, scaler_X, scaler_y, feature_columns, user_country, user_year)
# Out:
# Enter country name:  India
# Enter a year between 2017 and 2020:  2020
# Country: India, Year: 2020
# Actual 'Total Disasters': 11
# Predicted 'Total Disasters': 10.66
# Accuracy: 96.94%

# %%
# Example usage
user_country = input("Enter country name: ")
user_year = input("Enter a year between 2017 
and 2020: ")

predict_disaster_for_country_year(data, model, scaler_X, scaler_y, feature_columns, user_country, user_year)
# Out:
# Enter country name:  Brazil
# Enter a year between 2017 and 2020:  2019
# Country: Brazil, Year: 2019
# Actual 'Total Disasters': 8
# Predicted 'Total Disasters': 6.84
# Accuracy: 85.52%
